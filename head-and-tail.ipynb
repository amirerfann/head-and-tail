# %%
import requests
import pandas as pd
import backtrader as bt
from datetime import datetime
import random

# %%
# Data fetching functions (unchanged)
def get_datetime_timestamp(date_str):
    return int(pd.to_datetime(date_str).timestamp())

def ohlcv(symbol, resolution, start, stop):
    base_url = 'https://api.nobitex.ir/market/udf/history'
    ohlc_url = f"{base_url}?symbol={symbol}&resolution={resolution}&from={start}&to={stop}"
    
    try:
        response = requests.get(ohlc_url)
        response.raise_for_status()
        data = response.json()
        
        if not data.get('t') or data['s'] != 'ok':
            raise ValueError("Invalid or empty data returned from API")
        
        ohlcv_data = pd.DataFrame({
            'DateTime': data['t'],
            'Open': data['o'],
            'High': data['h'],
            'Low': data['l'],
            'Close': data['c'],
            'Volume': data['v']
        })
        
        ohlcv_data['DateTime'] = pd.to_datetime(ohlcv_data['DateTime'], unit='s')
        ohlcv_data.to_csv('dataset.csv', index=False, date_format='%Y-%m-%d %H:%M:%S')
        print(f"Data fetched: {len(ohlcv_data)} bars for {symbol} from {start} to {stop}")
        return ohlcv_data
    
    except requests.RequestException as e:
        print(f"Error fetching data: {e}")
        return pd.DataFrame()
    except ValueError as e:
        print(f"Data error: {e}")
        return pd.DataFrame()

# %%
# Leverage Sizer (unchanged)
class LeverageSizer(bt.Sizer):
    params = (
        ('leverage', 5.0),
        ('min_size', 0.0001),
        ('margin_buffer', 0.9),  # Use 90% of available cash to avoid margin issues
    )

    def _getsizing(self, comminfo, cash, data, isbuy):
        price = data.close[0]
        position_size = (cash * self.params.leverage * self.params.margin_buffer) / price
        position_size = max(position_size, self.params.min_size)
        self.log(f"Position size: {position_size:.6f}, cash={cash:.2f}, price={price:.2f}, margin_required={position_size * price / self.params.leverage:.2f}")
        return position_size

    def log(self, txt):
        print(f"Sizer: {txt}")

# %%
# Coin Flip Strategy with PnL calculation
class CoinFlipStrategy(bt.Strategy):
    params = (
        ('tp_percent', 0.015),  # 1% take profit
        ('sl_percent', 0.005),  # 0.5% stop loss
        ('leverage', 5.0),  # 5x leverage
        ('min_cash', 0.01),  # Minimum cash to trade
    )

    def __init__(self):
        self.pending_order = None
        self.entry_price = None
        self.entry_size = None
        self.is_long = None
        self.heads = 0
        self.tails = 0
        self.trade_pnls = []  # List to store PnL for each trade
        self.log("Strategy initialized")

    def log(self, txt):
        dt = self.datas[0].datetime.date(0) if self.datas else "Unknown Date"
        print(f"{dt}: {txt}")

    def notify_order(self, order):
        status_map = {
            0: "Created", 1: "Submitted", 2: "Accepted", 3: "Partial",
            4: "Completed", 5: "Canceled", 6: "Expired", 7: "Margin", 8: "Rejected"
        }
        
        if order.status in [order.Completed]:
            if order.isbuy():
                if self.position:  # Opening a long position
                    self.log(f"BUY EXECUTED (OPEN LONG), Price: {order.executed.price:.2f}, Size: {order.executed.size:.6f}")
                    self.entry_price = order.executed.price
                    self.entry_size = order.executed.size
                    self.is_long = True
                else:  # Closing a short position
                    exit_price = order.executed.price
                    # Calculate PnL for short: (entry_price - exit_price) * size * leverage
                    pnl = (self.entry_price - exit_price) * self.entry_size * self.params.leverage
                    self.trade_pnls.append(pnl)
                    self.log(f"BUY EXECUTED (CLOSE SHORT), Price: {exit_price:.2f}, Size: {order.executed.size:.6f}, PnL: {pnl:.2f}")
            elif order.issell():
                if self.position:  # Opening a short position
                    self.log(f"SELL EXECUTED (OPEN SHORT), Price: {order.executed.price:.2f}, Size: {order.executed.size:.6f}")
                    self.entry_price = order.executed.price
                    self.entry_size = order.executed.size
                    self.is_long = False
                else:  # Closing a long position
                    exit_price = order.executed.price
                    # Calculate PnL for long: (exit_price - entry_price) * size * leverage
                    pnl = (exit_price - self.entry_price) * self.entry_size * self.params.leverage
                    self.trade_pnls.append(pnl)
                    self.log(f"SELL EXECUTED (CLOSE LONG), Price: {exit_price:.2f}, Size: {order.executed.size:.6f}, PnL: {pnl:.2f}")
            self.pending_order = None
            self.log("Pending order cleared")

        elif order.status in [order.Canceled, order.Margin, order.Rejected, order.Expired]:
            self.log(f"Order Failed: Status={status_map.get(order.status, 'Unknown')}, Size={order.size:.6f}, Price={order.price:.2f}")
            self.pending_order = None
            self.log("Pending order cleared due to failure")

    def next(self):
        if self.pending_order or self.position:
            return

        price = self.data.close[0]
        cash = self.broker.get_cash()

        if cash < self.params.min_cash:
            self.log(f"Not enough cash to trade: {cash:.2f}")
            return

        flip = random.choice(['head', 'tail'])
        if flip == 'head':
            self.heads += 1
            tp = price * (1 + self.params.tp_percent)
            sl = price * (1 - self.params.sl_percent)
            self.pending_order = self.buy_bracket(
                price=price,
                limitprice=tp,
                stopprice=sl,
                exectype=bt.Order.Market
            )
            self.log(f"HEAD → BUY ORDER PLACED: Price={price:.2f}, TP={tp:.2f}, SL={sl:.2f}")
        else:
            self.tails += 1
            tp = price * (1 - self.params.tp_percent)
            sl = price * (1 + self.params.sl_percent)
            self.pending_order = self.sell_bracket(
                price=price,
                limitprice=tp,
                stopprice=sl,
                exectype=bt.Order.Market
            )
            self.log(f"TAIL → SELL ORDER PLACED: Price={price:.2f}, TP={tp:.2f}, SL={sl:.2f}")

# %%
if __name__ == '__main__':
    # Fetch data
    start = get_datetime_timestamp('2020-04-20')
    stop = get_datetime_timestamp('2025-04-25')
    df = ohlcv('btcusdt', 1, start, stop)
    
    if df.empty:
        print("No data fetched, exiting")
        exit(1)

    # Prepare data
    df = pd.read_csv('dataset.csv')
    df['DateTime'] = pd.to_datetime(df['DateTime'])
    df.set_index('DateTime', inplace=True)
    
    data = bt.feeds.PandasData(
        dataname=df,
        timeframe=bt.TimeFrame.Minutes,
        openinterest=-1
    )
    
    # Setup Cerebro
    cerebro = bt.Cerebro()
    cerebro.addstrategy(CoinFlipStrategy)
    cerebro.adddata(data)
    cerebro.broker.setcash(1000.0)
    cerebro.broker.setcommission(commission=0.001, margin=0.2)  # 20% margin requirement (1/leverage)
    cerebro.addsizer(LeverageSizer)

    # Add analyzers
    cerebro.addanalyzer(bt.analyzers.SharpeRatio, _name='sharpe', riskfreerate=0.0)
    cerebro.addanalyzer(bt.analyzers.TradeAnalyzer, _name='trades')
    cerebro.addanalyzer(bt.analyzers.DrawDown, _name='drawdown')
    cerebro.addanalyzer(bt.analyzers.SQN, _name='sqn')

    # Run backtest
    results = cerebro.run()
    strat = results[0]
# Out:
# Data fetched: 40000 bars for btcusdt from 1587340800 to 1745539200
# 2025-04-24: Strategy initialized
# Sizer: Position size: 0.052278, cash=1000.00, price=86079.00, margin_required=900.00
# 2025-03-28: TAIL → SELL ORDER PLACED: Price=86079.00, TP=84787.82, SL=86509.39
# 2025-03-28: SELL EXECUTED (OPEN SHORT), Price: 86078.90, Size: -0.052278
# 2025-03-28: Pending order cleared
# 2025-03-28: BUY EXECUTED (CLOSE SHORT), Price: 84787.82, Size: 0.052278, PnL: -337.47
# 2025-03-28: Pending order cleared
# 2025-03-28: Order Failed: Status=Canceled, Size=0.052278, Price=86509.39
# 2025-03-28: Pending order cleared due to failure
# Sizer: Position size: 0.056677, cash=1067.49, price=84756.00, margin_required=960.75
# 2025-03-28: TAIL → SELL ORDER PLACED: Price=84756.00, TP=83484.66, SL=85179.78
# 2025-03-28: SELL EXECUTED (OPEN SHORT), Price: 84756.00, Size: -0.056677
# 2025-03-28: Pending order cleared
# 2025-03-29: BUY EXECUTED (CLOSE SHORT), Price: 83484.66, Size: 0.056677, PnL: -360.28
# 2025-03-29: Pending order cleared
# 2025-03-29: Order Failed: Status=Canceled, Size=0.056677, Price=85179.78
# 2025-03-29: Pending order cleared due to failure
# Sizer: Position size: 0.061487, cash=1139.55, price=83400.00, margin_required=1025.60
# 2025-03-29: TAIL → SELL ORDER PLACED: Price=83400.00, TP=82149.00, SL=83817.00
# 2025-03-29: SELL EXECUTED (OPEN SHORT), Price: 83429.97, Size: -0.061487
# 2025-03-29: Pending order cleared
# 2025-03-29: BUY EXECUTED (CLOSE SHORT), Price: 82149.00, Size: 0.061487, PnL: -393.81
# 2025-03-29: Pending order cleared
# 2025-03-29: Order Failed: Status=Canceled, Size=0.061487, Price=83817.00
# 2025-03-29: Pending order cleared due to failure
# Sizer: Position size: 0.066712, cash=1218.31, price=82180.00, margin_required=1096.48
# 2025-03-29: HEAD → BUY ORDER PLACED: Price=82180.00, TP=83412.70, SL=81769.10
# 2025-03-29: BUY EXECUTED (OPEN LONG), Price: 82120.00, Size: 0.066712
# 2025-03-29: Pending order cleared
# 2025-03-29: SELL EXECUTED (CLOSE LONG), Price: 83412.70, Size: -0.066712, PnL: 431.19
# 2025-03-29: Pending order cleared
# 2025-03-29: Order Failed: Status=Canceled, Size=-0.066712, Price=81769.10
# 2025-03-29: Pending order cleared due to failure
# Sizer: Position size: 0.071002, cash=1304.55, price=82680.00, margin_required=1174.10
# 2025-03-29: HEAD → BUY ORDER PLACED: Price=82680.00, TP=83920.20, SL=82266.60
# 2025-03-29: BUY EXECUTED (OPEN LONG), Price: 82677.82, Size: 0.071002
# 2025-03-29: Pending order cleared
# 2025-03-29: SELL EXECUTED (CLOSE LONG), Price: 83920.20, Size: -0.071002, PnL: 441.06
# 2025-03-29: Pending order cleared
# 2025-03-29: Order Failed: Status=Canceled, Size=-0.071002, Price=82266.60
# 2025-03-29: Pending order cleared due to failure
# Sizer: Position size: 0.075787, cash=1392.76, price=82698.22, margin_required=1253.49
# 2025-03-29: HEAD → BUY ORDER PLACED: Price=82698.22, TP=83938.69, SL=82284.73
# 2025-03-29: BUY EXECUTED (OPEN LONG), Price: 83254.88, Size: 0.075787
# 2025-03-29: Pending order cleared
# 2025-03-29: SELL EXECUTED (CLOSE LONG), Price: 83938.69, Size: -0.075787, PnL: 259.12
# 2025-03-29: Pending order cleared
# 2025-03-29: Order Failed: Status=Canceled, Size=-0.075787, Price=82284.73
# 2025-03-29: Pending order cleared due to failure
# Sizer: Position size: 0.077852, cash=1444.59, price=83500.00, margin_required=1300.13
# 2025-03-29: TAIL → SELL ORDER PLACED: Price=83500.00, TP=82247.50, SL=83917.50
# 2025-03-29: SELL EXECUTED (OPEN SHORT), Price: 82731.31, Size: -0.077852
# 2025-03-29: Pending order cleared
# 2025-03-29: BUY EXECUTED (CLOSE SHORT), Price: 83917.50, Size: 0.077852, PnL: 461.74
# 2025-03-29: Pending order cleared
# 2025-03-29: Order Failed: Status=Canceled, Size=0.077852, Price=82247.50
# 2025-03-29: Pending order cleared due to failure
# Sizer: Position size: 0.073560, cash=1352.24, price=82722.44, margin_required=1217.02
# 2025-03-29: TAIL → SELL ORDER PLACED: Price=82722.44, TP=81481.60, SL=83136.05
# 2025-03-29: SELL EXECUTED (OPEN SHORT), Price: 83301.42, Size: -0.073560
# 2025-03-29: Pending order cleared
# 2025-03-29: BUY EXECUTED (CLOSE SHORT), Price: 83136.05, Size: 0.073560, PnL: -60.82
# 2025-03-29: Pending order cleared
# 2025-03-29: Order Failed: Status=Canceled, Size=0.073560, Price=81481.60
# 2025-03-29: Pending order cleared due to failure
# Sizer: Position size: 0.073093, cash=1364.40, price=84000.00, margin_required=1227.96
# 2025-03-29: TAIL → SELL ORDER PLACED: Price=84000.00, TP=82740.00, SL=84420.00
# 2025-03-29: SELL EXECUTED (OPEN SHORT), Price: 83610.00, Size: -0.073093
# 2025-03-29: Pending order cleared
# 2025-03-29: BUY EXECUTED (CLOSE SHORT), Price: 82350.00, Size: 0.073093, PnL: -460.49
# 2025-03-29: Pending order cleared
# 2025-03-29: Order Failed: Status=Canceled, Size=0.073093, Price=84420.00
# 2025-03-29: Pending order cleared due to failure
# Sizer: Position size: 0.079576, cash=1456.50, price=82364.45, margin_required=1310.85
# 2025-03-29: HEAD → BUY ORDER PLACED: Price=82364.45, TP=83599.92, SL=81952.63
# 2025-03-29: BUY EXECUTED (OPEN LONG), Price: 82364.45, Size: 0.079576
# 2025-03-29: Pending order cleared
# 2025-03-29: SELL EXECUTED (CLOSE LONG), Price: 81952.63, Size: -0.079576, PnL: -163.86
# 2025-03-29: Pending order cleared
# 2025-03-29: Order Failed: Status=Canceled, Size=-0.079576, Price=83599.92
# 2025-03-29: Pending order cleared due to failure
# Sizer: Position size: 0.078323, cash=1423.73, price=81800.00, margin_required=1281.36
# 2025-03-29: HEAD → BUY ORDER PLACED: Price=81800.00, TP=83027.00, SL=81391.00
# 2025-03-29: BUY EXECUTED (OPEN LONG), Price: 81800.00, Size: 0.078323
# 2025-03-29: Pending order cleared
# 2025-03-30: SELL EXECUTED (CLOSE LONG), Price: 83049.98, Size: -0.078323, PnL: 489.51
# 2025-03-30: Pending order cleared
# 2025-03-30: Order Failed: Status=Canceled, Size=-0.078323, Price=81391.00
# 2025-03-30: Pending order cleared due to failure
# Sizer: Position size: 0.082488, cash=1521.63, price=83010.00, margin_required=1369.47
# 2025-03-30: TAIL → SELL ORDER PLACED: Price=83010.00, TP=81764.85, SL=83425.05
# 2025-03-30: SELL EXECUTED (OPEN SHORT), Price: 83010.00, Size: -0.082488
# 2025-03-30: Pending order cleared
# 2025-03-30: BUY EXECUTED (CLOSE SHORT), Price: 83425.05, Size: 0.082488, PnL: 171.18
# 2025-03-30: Pending order cleared
# 2025-03-30: Order Failed: Status=Canceled, Size=0.082488, Price=81764.85
# 2025-03-30: Pending order cleared due to failure
# Sizer: Position size: 0.080255, cash=1487.39, price=83400.00, margin_required=1338.65
# 2025-03-30: HEAD → BUY ORDER PLACED: Price=83400.00, TP=84651.00, SL=82983.00
# 2025-03-30: BUY EXECUTED (OPEN LONG), Price: 83400.00, Size: 0.080255
# 2025-03-30: Pending order cleared
# 2025-03-30: SELL EXECUTED (CLOSE LONG), Price: 82983.00, Size: -0.080255, PnL: -167.33
# 2025-03-30: Pending order cleared
# 2025-03-30: Order Failed: Status=Canceled, Size=-0.080255, Price=84651.00
# 2025-03-30: Pending order cleared due to failure
# Sizer: Position size: 0.078875, cash=1453.93, price=82950.06, margin_required=1308.54
# 2025-03-30: HEAD → BUY ORDER PLACED: Price=82950.06, TP=84194.31, SL=82535.31
# 2025-03-30: BUY EXECUTED (OPEN LONG), Price: 82950.06, Size: 0.078875
# 2025-03-30: Pending order cleared
# 2025-03-30: SELL EXECUTED (CLOSE LONG), Price: 82535.31, Size: -0.078875, PnL: -163.57
# 2025-03-30: Pending order cleared
# 2025-03-30: Order Failed: Status=Canceled, Size=-0.078875, Price=84194.31
# 2025-03-30: Pending order cleared due to failure
# Sizer: Position size: 0.077521, cash=1421.21, price=82500.00, margin_required=1279.09
# 2025-03-30: TAIL → SELL ORDER PLACED: Price=82500.00, TP=81262.50, SL=82912.50
# 2025-03-30: SELL EXECUTED (OPEN SHORT), Price: 82500.20, Size: -0.077521
# 2025-03-30: Pending order cleared
# 2025-03-30: BUY EXECUTED (CLOSE SHORT), Price: 82912.50, Size: 0.077521, PnL: 159.81
# 2025-03-30: Pending order cleared
# 2025-03-30: Order Failed: Status=Canceled, Size=0.077521, Price=81262.50
# 2025-03-30: Pending order cleared due to failure
# Sizer: Position size: 0.075503, cash=1389.25, price=82800.15, margin_required=1250.33
# 2025-03-30: HEAD → BUY ORDER PLACED: Price=82800.15, TP=84042.15, SL=82386.15
# 2025-03-30: BUY EXECUTED (OPEN LONG), Price: 82994.60, Size: 0.075503
# 2025-03-30: Pending order cleared
# 2025-03-30: SELL EXECUTED (CLOSE LONG), Price: 82386.15, Size: -0.075503, PnL: -229.70
# 2025-03-30: Pending order cleared
# 2025-03-30: Order Failed: Status=Canceled, Size=-0.075503, Price=84042.15
# 2025-03-30: Pending order cleared due to failure
# Sizer: Position size: 0.073450, cash=1343.31, price=82300.00, margin_required=1208.98
# 2025-03-30: TAIL → SELL ORDER PLACED: Price=82300.00, TP=81065.50, SL=82711.50
# 2025-03-30: SELL EXECUTED (OPEN SHORT), Price: 82301.44, Size: -0.073450
# 2025-03-30: Pending order cleared
# 2025-03-30: BUY EXECUTED (CLOSE SHORT), Price: 82711.50, Size: 0.073450, PnL: 150.59
# 2025-03-30: Pending order cleared
# 2025-03-30: Order Failed: Status=Canceled, Size=0.073450, Price=81065.50
# 2025-03-30: Pending order cleared due to failure
# Sizer: Position size: 0.071370, cash=1313.19, price=82799.11, margin_required=1181.87
# 2025-03-30: HEAD → BUY ORDER PLACED: Price=82799.11, TP=84041.10, SL=82385.11
# 2025-03-30: BUY EXECUTED (OPEN LONG), Price: 82790.88, Size: 0.071370
# 2025-03-30: Pending order cleared
# 2025-03-30: SELL EXECUTED (CLOSE LONG), Price: 82385.11, Size: -0.071370, PnL: -144.80
# 2025-03-30: Pending order cleared
# 2025-03-30: Order Failed: Status=Canceled, Size=-0.071370, Price=84041.10
# 2025-03-30: Pending order cleared due to failure
# Sizer: Position size: 0.070049, cash=1284.23, price=82500.00, margin_required=1155.81
# 2025-03-30: HEAD → BUY ORDER PLACED: Price=82500.00, TP=83737.50, SL=82087.50
# 2025-03-30: BUY EXECUTED (OPEN LONG), Price: 82539.76, Size: 0.070049
# 2025-03-30: Pending order cleared
# 2025-03-30: SELL EXECUTED (CLOSE LONG), Price: 82087.50, Size: -0.070049, PnL: -158.40
# 2025-03-30: Pending order cleared
# 2025-03-30: Order Failed: Status=Canceled, Size=-0.070049, Price=83737.50
# 2025-03-30: Pending order cleared due to failure
# Sizer: Position size: 0.068738, cash=1252.55, price=82000.00, margin_required=1127.30
# 2025-03-30: HEAD → BUY ORDER PLACED: Price=82000.00, TP=83230.00, SL=81590.00
# 2025-03-30: BUY EXECUTED (OPEN LONG), Price: 82000.00, Size: 0.068738
# 2025-03-30: Pending order cleared
# 2025-03-31: SELL EXECUTED (CLOSE LONG), Price: 81590.00, Size: -0.068738, PnL: -140.91
# 2025-03-31: Pending order cleared
# 2025-03-31: Order Failed: Status=Canceled, Size=-0.068738, Price=83230.00
# 2025-03-31: Pending order cleared due to failure
# Sizer: Position size: 0.067603, cash=1224.37, price=81500.00, margin_required=1101.93
# 2025-03-31: TAIL → SELL ORDER PLACED: Price=81500.00, TP=80277.50, SL=81907.50
# 2025-03-31: SELL EXECUTED (OPEN SHORT), Price: 81501.00, Size: -0.067603
# 2025-03-31: Pending order cleared
# 2025-03-31: BUY EXECUTED (CLOSE SHORT), Price: 81907.50, Size: 0.067603, PnL: 137.40
# 2025-03-31: Pending order cleared
# 2025-03-31: Order Failed: Status=Canceled, Size=0.067603, Price=80277.50
# 2025-03-31: Pending order cleared due to failure
# Sizer: Position size: 0.065683, cash=1196.89, price=81999.91, margin_required=1077.20
# 2025-03-31: HEAD → BUY ORDER PLACED: Price=81999.91, TP=83229.91, SL=81589.91
# 2025-03-31: BUY EXECUTED (OPEN LONG), Price: 81999.55, Size: 0.065683
# 2025-03-31: Pending order cleared
# 2025-03-31: SELL EXECUTED (CLOSE LONG), Price: 81589.91, Size: -0.065683, PnL: -134.53
# 2025-03-31: Pending order cleared
# 2025-03-31: Order Failed: Status=Canceled, Size=-0.065683, Price=83229.91
# 2025-03-31: Pending order cleared due to failure
# Sizer: Position size: 0.064565, cash=1169.98, price=81545.03, margin_required=1052.99
# 2025-03-31: TAIL → SELL ORDER PLACED: Price=81545.03, TP=80321.85, SL=81952.76
# 2025-03-31: SELL EXECUTED (OPEN SHORT), Price: 81545.03, Size: -0.064565
# 2025-03-31: Pending order cleared
# 2025-03-31: BUY EXECUTED (CLOSE SHORT), Price: 81968.00, Size: 0.064565, PnL: 136.54
# 2025-03-31: Pending order cleared
# 2025-03-31: Order Failed: Status=Canceled, Size=0.064565, Price=80321.85
# 2025-03-31: Pending order cleared due to failure
# Sizer: Position size: 0.062731, cash=1142.67, price=81969.37, margin_required=1028.41
# 2025-03-31: TAIL → SELL ORDER PLACED: Price=81969.37, TP=80739.83, SL=82379.22
# 2025-03-31: SELL EXECUTED (OPEN SHORT), Price: 81817.01, Size: -0.062731
# 2025-03-31: Pending order cleared
# 2025-03-31: BUY EXECUTED (CLOSE SHORT), Price: 82379.22, Size: 0.062731, PnL: 176.34
# 2025-03-31: Pending order cleared
# 2025-03-31: Order Failed: Status=Canceled, Size=0.062731, Price=80739.83
# 2025-03-31: Pending order cleared due to failure
# Sizer: Position size: 0.060441, cash=1107.41, price=82450.00, margin_required=996.67
# 2025-03-31: HEAD → BUY ORDER PLACED: Price=82450.00, TP=83686.75, SL=82037.75
# 2025-03-31: BUY EXECUTED (OPEN LONG), Price: 82450.00, Size: 0.060441
# 2025-03-31: Pending order cleared
# 2025-03-31: SELL EXECUTED (CLOSE LONG), Price: 82037.75, Size: -0.060441, PnL: -124.58
# 2025-03-31: Pending order cleared
# 2025-03-31: Order Failed: Status=Canceled, Size=-0.060441, Price=83686.75
# 2025-03-31: Pending order cleared due to failure
# Sizer: Position size: 0.059405, cash=1082.49, price=82000.00, margin_required=974.24
# 2025-03-31: TAIL → SELL ORDER PLACED: Price=82000.00, TP=80770.00, SL=82410.00
# 2025-03-31: SELL EXECUTED (OPEN SHORT), Price: 81990.00, Size: -0.059405
# 2025-03-31: Pending order cleared
# 2025-03-31: BUY EXECUTED (CLOSE SHORT), Price: 82410.00, Size: 0.059405, PnL: 124.75
# 2025-03-31: Pending order cleared
# 2025-03-31: Order Failed: Status=Canceled, Size=0.059405, Price=80770.00
# 2025-03-31: Pending order cleared due to failure
# Sizer: Position size: 0.057662, cash=1057.54, price=82531.48, margin_required=951.79
# 2025-03-31: TAIL → SELL ORDER PLACED: Price=82531.48, TP=81293.51, SL=82944.14
# 2025-03-31: SELL EXECUTED (OPEN SHORT), Price: 82599.00, Size: -0.057662
# 2025-03-31: Pending order cleared
# 2025-03-31: BUY EXECUTED (CLOSE SHORT), Price: 82944.14, Size: 0.057662, PnL: 99.51
# 2025-03-31: Pending order cleared
# 2025-03-31: Order Failed: Status=Canceled, Size=0.057662, Price=81293.51
# 2025-03-31: Pending order cleared due to failure
# Sizer: Position size: 0.056396, cash=1037.64, price=82796.39, margin_required=933.87
# 2025-03-31: HEAD → BUY ORDER PLACED: Price=82796.39, TP=84038.34, SL=82382.41
# 2025-03-31: BUY EXECUTED (OPEN LONG), Price: 82896.39, Size: 0.056396
# 2025-03-31: Pending order cleared
# 2025-03-31: SELL EXECUTED (CLOSE LONG), Price: 82382.41, Size: -0.056396, PnL: -144.93
# 2025-03-31: Pending order cleared
# 2025-03-31: Order Failed: Status=Canceled, Size=-0.056396, Price=84038.34
# 2025-03-31: Pending order cleared due to failure
# Sizer: Position size: 0.055084, cash=1008.65, price=82400.00, margin_required=907.79
# 2025-03-31: TAIL → SELL ORDER PLACED: Price=82400.00, TP=81164.00, SL=82812.00
# 2025-03-31: SELL EXECUTED (OPEN SHORT), Price: 82400.00, Size: -0.055084
# 2025-03-31: Pending order cleared
# 2025-04-01: BUY EXECUTED (CLOSE SHORT), Price: 82830.00, Size: 0.055084, PnL: 118.43
# 2025-04-01: Pending order cleared
# 2025-04-01: Order Failed: Status=Canceled, Size=0.055084, Price=81164.00
# 2025-04-01: Pending order cleared due to failure
# Sizer: Position size: 0.053507, cash=984.97, price=82836.00, margin_required=886.47
# 2025-04-01: HEAD → BUY ORDER PLACED: Price=82836.00, TP=84078.54, SL=82421.82
# 2025-04-01: BUY EXECUTED (OPEN LONG), Price: 82836.00, Size: 0.053507
# 2025-04-01: Pending order cleared
# 2025-04-01: SELL EXECUTED (CLOSE LONG), Price: 84078.54, Size: -0.053507, PnL: 332.43
# 2025-04-01: Pending order cleared
# 2025-04-01: Order Failed: Status=Canceled, Size=-0.053507, Price=82421.82
# 2025-04-01: Pending order cleared due to failure
# Sizer: Position size: 0.056261, cash=1051.45, price=84100.00, margin_required=946.31
# 2025-04-01: HEAD → BUY ORDER PLACED: Price=84100.00, TP=85361.50, SL=83679.50
# 2025-04-01: BUY EXECUTED (OPEN LONG), Price: 84100.00, Size: 0.056261
# 2025-04-01: Pending order cleared
# 2025-04-01: SELL EXECUTED (CLOSE LONG), Price: 83679.50, Size: -0.056261, PnL: -118.29
# 2025-04-01: Pending order cleared
# 2025-04-01: Order Failed: Status=Canceled, Size=-0.056261, Price=85361.50
# 2025-04-01: Pending order cleared due to failure
# Sizer: Position size: 0.055280, cash=1027.79, price=83666.27, margin_required=925.01
# 2025-04-01: TAIL → SELL ORDER PLACED: Price=83666.27, TP=82411.28, SL=84084.60
# 2025-04-01: SELL EXECUTED (OPEN SHORT), Price: 83615.00, Size: -0.055280
# 2025-04-01: Pending order cleared
# 2025-04-01: BUY EXECUTED (CLOSE SHORT), Price: 82411.28, Size: 0.055280, PnL: -332.71
# 2025-04-01: Pending order cleared
# 2025-04-01: Order Failed: Status=Canceled, Size=0.055280, Price=84084.60
# 2025-04-01: Pending order cleared due to failure
# Sizer: Position size: 0.059691, cash=1094.33, price=82500.03, margin_required=984.90
# 2025-04-01: HEAD → BUY ORDER PLACED: Price=82500.03, TP=83737.53, SL=82087.53
# 2025-04-01: BUY EXECUTED (OPEN LONG), Price: 82500.03, Size: 0.059691
# 2025-04-01: Pending order cleared
# 2025-04-01: SELL EXECUTED (CLOSE LONG), Price: 83737.53, Size: -0.059691, PnL: 369.34
# 2025-04-01: Pending order cleared
# 2025-04-01: Order Failed: Status=Canceled, Size=-0.059691, Price=82087.53
# 2025-04-01: Pending order cleared due to failure
# Sizer: Position size: 0.062733, cash=1168.20, price=83798.01, margin_required=1051.38
# 2025-04-01: HEAD → BUY ORDER PLACED: Price=83798.01, TP=85054.98, SL=83379.02
# 2025-04-01: BUY EXECUTED (OPEN LONG), Price: 83800.00, Size: 0.062733
# 2025-04-01: Pending order cleared
# 2025-04-01: SELL EXECUTED (CLOSE LONG), Price: 83379.02, Size: -0.062733, PnL: -132.05
# 2025-04-01: Pending order cleared
# 2025-04-01: Order Failed: Status=Canceled, Size=-0.062733, Price=85054.98
# 2025-04-01: Pending order cleared due to failure
# Sizer: Position size: 0.061262, cash=1141.79, price=83870.00, margin_required=1027.61
# 2025-04-01: TAIL → SELL ORDER PLACED: Price=83870.00, TP=82611.95, SL=84289.35
# 2025-04-01: SELL EXECUTED (OPEN SHORT), Price: 83870.00, Size: -0.061262
# 2025-04-01: Pending order cleared
# 2025-04-01: BUY EXECUTED (CLOSE SHORT), Price: 84289.35, Size: 0.061262, PnL: 128.45
# 2025-04-01: Pending order cleared
# 2025-04-01: Order Failed: Status=Canceled, Size=0.061262, Price=82611.95
# 2025-04-01: Pending order cleared due to failure
# Sizer: Position size: 0.059574, cash=1116.10, price=84306.32, margin_required=1004.49
# 2025-04-01: HEAD → BUY ORDER PLACED: Price=84306.32, TP=85570.91, SL=83884.79
# 2025-04-01: BUY EXECUTED (OPEN LONG), Price: 84317.02, Size: 0.059574
# 2025-04-01: Pending order cleared
# 2025-04-02: SELL EXECUTED (CLOSE LONG), Price: 83884.79, Size: -0.059574, PnL: -128.75
# 2025-04-02: Pending order cleared
# 2025-04-02: Order Failed: Status=Canceled, Size=-0.059574, Price=85570.91
# 2025-04-02: Pending order cleared due to failure
# Sizer: Position size: 0.058517, cash=1090.35, price=83848.30, margin_required=981.32
# 2025-04-02: TAIL → SELL ORDER PLACED: Price=83848.30, TP=82590.58, SL=84267.54
# 2025-04-02: SELL EXECUTED (OPEN SHORT), Price: 83848.30, Size: -0.058517
# 2025-04-02: Pending order cleared
# 2025-04-02: BUY EXECUTED (CLOSE SHORT), Price: 84267.54, Size: 0.058517, PnL: 122.66
# 2025-04-02: Pending order cleared
# 2025-04-02: Order Failed: Status=Canceled, Size=0.058517, Price=82590.58
# 2025-04-02: Pending order cleared due to failure
# Sizer: Position size: 0.056797, cash=1065.82, price=84443.99, margin_required=959.24
# 2025-04-02: TAIL → SELL ORDER PLACED: Price=84443.99, TP=83177.33, SL=84866.21
# 2025-04-02: SELL EXECUTED (OPEN SHORT), Price: 84443.99, Size: -0.056797
# 2025-04-02: Pending order cleared
# 2025-04-02: BUY EXECUTED (CLOSE SHORT), Price: 84866.21, Size: 0.056797, PnL: 119.90
# 2025-04-02: Pending order cleared
# 2025-04-02: Order Failed: Status=Canceled, Size=0.056797, Price=83177.33
# 2025-04-02: Pending order cleared due to failure
# Sizer: Position size: 0.055187, cash=1041.84, price=84953.10, margin_required=937.65
# 2025-04-02: TAIL → SELL ORDER PLACED: Price=84953.10, TP=83678.80, SL=85377.87
# 2025-04-02: SELL EXECUTED (OPEN SHORT), Price: 85000.00, Size: -0.055187
# 2025-04-02: Pending order cleared
# 2025-04-02: BUY EXECUTED (CLOSE SHORT), Price: 85377.87, Size: 0.055187, PnL: 104.27
# 2025-04-02: Pending order cleared
# 2025-04-02: Order Failed: Status=Canceled, Size=0.055187, Price=83678.80
# 2025-04-02: Pending order cleared due to failure
# Sizer: Position size: 0.053800, cash=1020.98, price=85399.00, margin_required=918.89
# 2025-04-02: TAIL → SELL ORDER PLACED: Price=85399.00, TP=84118.01, SL=85825.99
# 2025-04-02: SELL EXECUTED (OPEN SHORT), Price: 85399.00, Size: -0.053800
# 2025-04-02: Pending order cleared
# 2025-04-02: BUY EXECUTED (CLOSE SHORT), Price: 85825.99, Size: 0.053800, PnL: 114.86
# 2025-04-02: Pending order cleared
# 2025-04-02: Order Failed: Status=Canceled, Size=0.053800, Price=84118.01
# 2025-04-02: Pending order cleared due to failure
# Sizer: Position size: 0.052325, cash=998.01, price=85830.00, margin_required=898.21
# 2025-04-02: HEAD → BUY ORDER PLACED: Price=85830.00, TP=87117.45, SL=85400.85
# 2025-04-02: BUY EXECUTED (OPEN LONG), Price: 85830.02, Size: 0.052325
# 2025-04-02: Pending order cleared
# 2025-04-02: SELL EXECUTED (CLOSE LONG), Price: 85400.85, Size: -0.052325, PnL: -112.28
# 2025-04-02: Pending order cleared
# 2025-04-02: Order Failed: Status=Canceled, Size=-0.052325, Price=87117.45
# 2025-04-02: Pending order cleared due to failure
# Sizer: Position size: 0.051345, cash=975.56, price=85500.00, margin_required=878.00
# 2025-04-02: TAIL → SELL ORDER PLACED: Price=85500.00, TP=84217.50, SL=85927.50
# 2025-04-02: SELL EXECUTED (OPEN SHORT), Price: 85580.00, Size: -0.051345
# 2025-04-02: Pending order cleared
# 2025-04-02: BUY EXECUTED (CLOSE SHORT), Price: 85927.50, Size: 0.051345, PnL: 89.21
# 2025-04-02: Pending order cleared
# 2025-04-02: Order Failed: Status=Canceled, Size=0.051345, Price=84217.50
# 2025-04-02: Pending order cleared due to failure
# Sizer: Position size: 0.050113, cash=957.71, price=86000.00, margin_required=861.94
# 2025-04-02: HEAD → BUY ORDER PLACED: Price=86000.00, TP=87290.00, SL=85570.00
# 2025-04-02: BUY EXECUTED (OPEN LONG), Price: 86083.88, Size: 0.050113
# 2025-04-02: Pending order cleared
# 2025-04-02: SELL EXECUTED (CLOSE LONG), Price: 85570.00, Size: -0.050113, PnL: -128.76
# 2025-04-02: Pending order cleared
# 2025-04-02: Order Failed: Status=Canceled, Size=-0.050113, Price=87290.00
# 2025-04-02: Pending order cleared due to failure
# Sizer: Position size: 0.049125, cash=931.96, price=85370.00, margin_required=838.77
# 2025-04-02: HEAD → BUY ORDER PLACED: Price=85370.00, TP=86650.55, SL=84943.15
# 2025-04-02: BUY EXECUTED (OPEN LONG), Price: 85700.00, Size: 0.049125
# 2025-04-02: Pending order cleared
# 2025-04-02: SELL EXECUTED (CLOSE LONG), Price: 86650.55, Size: -0.049125, PnL: 233.48
# 2025-04-02: Pending order cleared
# 2025-04-02: Order Failed: Status=Canceled, Size=-0.049125, Price=84943.15
# 2025-04-02: Pending order cleared due to failure
# Sizer: Position size: 0.050708, cash=978.66, price=86850.00, margin_required=880.79
# 2025-04-02: HEAD → BUY ORDER PLACED: Price=86850.00, TP=88152.75, SL=86415.75
# 2025-04-02: BUY EXECUTED (OPEN LONG), Price: 86850.00, Size: 0.050708
# 2025-04-02: Pending order cleared
# 2025-04-02: SELL EXECUTED (CLOSE LONG), Price: 86415.75, Size: -0.050708, PnL: -110.10
# 2025-04-02: Pending order cleared
# 2025-04-02: Order Failed: Status=Canceled, Size=-0.050708, Price=88152.75
# 2025-04-02: Pending order cleared due to failure
# Sizer: Position size: 0.049966, cash=956.64, price=86156.07, margin_required=860.97
# 2025-04-02: HEAD → BUY ORDER PLACED: Price=86156.07, TP=87448.41, SL=85725.29
# 2025-04-02: BUY EXECUTED (OPEN LONG), Price: 86050.00, Size: 0.049966
# 2025-04-02: Pending order cleared
# 2025-04-02: SELL EXECUTED (CLOSE LONG), Price: 85331.00, Size: -0.049966, PnL: -179.63
# 2025-04-02: Pending order cleared
# 2025-04-02: Order Failed: Status=Canceled, Size=-0.049966, Price=87448.41
# 2025-04-02: Pending order cleared due to failure
# Sizer: Position size: 0.048668, cash=920.71, price=85132.00, margin_required=828.64
# 2025-04-02: HEAD → BUY ORDER PLACED: Price=85132.00, TP=86408.98, SL=84706.34
# 2025-04-02: BUY EXECUTED (OPEN LONG), Price: 85070.01, Size: 0.048668
# 2025-04-02: Pending order cleared
# 2025-04-02: SELL EXECUTED (CLOSE LONG), Price: 84706.34, Size: -0.048668, PnL: -88.50
# 2025-04-02: Pending order cleared
# 2025-04-02: Order Failed: Status=Canceled, Size=-0.048668, Price=86408.98
# 2025-04-02: Pending order cleared due to failure
# Sizer: Position size: 0.048047, cash=903.01, price=84574.01, margin_required=812.71
# 2025-04-02: TAIL → SELL ORDER PLACED: Price=84574.01, TP=83305.40, SL=84996.88
# 2025-04-02: SELL EXECUTED (OPEN SHORT), Price: 84570.00, Size: -0.048047
# 2025-04-02: Pending order cleared
# 2025-04-02: BUY EXECUTED (CLOSE SHORT), Price: 83305.40, Size: 0.048047, PnL: -303.80
# 2025-04-02: Pending order cleared
# 2025-04-02: Order Failed: Status=Canceled, Size=0.048047, Price=84996.88
# 2025-04-02: Pending order cleared due to failure
# Sizer: Position size: 0.051999, cash=963.77, price=83405.01, margin_required=867.40
# 2025-04-02: HEAD → BUY ORDER PLACED: Price=83405.01, TP=84656.09, SL=82987.98
# 2025-04-02: BUY EXECUTED (OPEN LONG), Price: 83405.01, Size: 0.051999
# 2025-04-02: Pending order cleared
# 2025-04-02: SELL EXECUTED (CLOSE LONG), Price: 82987.98, Size: -0.051999, PnL: -108.42
# 2025-04-02: Pending order cleared
# 2025-04-02: Order Failed: Status=Canceled, Size=-0.051999, Price=84656.09
# 2025-04-02: Pending order cleared due to failure
# Sizer: Position size: 0.051139, cash=942.09, price=82900.00, margin_required=847.88
# 2025-04-02: HEAD → BUY ORDER PLACED: Price=82900.00, TP=84143.50, SL=82485.50
# 2025-04-02: BUY EXECUTED (OPEN LONG), Price: 82900.00, Size: 0.051139
# 2025-04-02: Pending order cleared
# 2025-04-02: SELL EXECUTED (CLOSE LONG), Price: 82485.50, Size: -0.051139, PnL: -105.98
# 2025-04-02: Pending order cleared
# 2025-04-02: Order Failed: Status=Canceled, Size=-0.051139, Price=84143.50
# 2025-04-02: Pending order cleared due to failure
# Sizer: Position size: 0.050255, cash=920.89, price=82460.00, margin_required=828.80
# 2025-04-02: HEAD → BUY ORDER PLACED: Price=82460.00, TP=83696.90, SL=82047.70
# 2025-04-02: BUY EXECUTED (OPEN LONG), Price: 82445.00, Size: 0.050255
# 2025-04-02: Pending order cleared
# 2025-04-03: SELL EXECUTED (CLOSE LONG), Price: 83700.00, Size: -0.050255, PnL: 315.35
# 2025-04-03: Pending order cleared
# 2025-04-03: Order Failed: Status=Canceled, Size=-0.050255, Price=82047.70
# 2025-04-03: Pending order cleared due to failure
# Sizer: Position size: 0.052901, cash=983.96, price=83700.00, margin_required=885.56
# 2025-04-03: TAIL → SELL ORDER PLACED: Price=83700.00, TP=82444.50, SL=84118.50
# 2025-04-03: SELL EXECUTED (OPEN SHORT), Price: 83749.98, Size: -0.052901
# 2025-04-03: Pending order cleared
# 2025-04-03: BUY EXECUTED (CLOSE SHORT), Price: 82444.50, Size: 0.052901, PnL: -345.31
# 2025-04-03: Pending order cleared
# 2025-04-03: Order Failed: Status=Canceled, Size=0.052901, Price=84118.50
# 2025-04-03: Pending order cleared due to failure
# Sizer: Position size: 0.057507, cash=1053.02, price=82400.00, margin_required=947.72
# 2025-04-03: TAIL → SELL ORDER PLACED: Price=82400.00, TP=81164.00, SL=82812.00
# 2025-04-03: SELL EXECUTED (OPEN SHORT), Price: 82450.55, Size: -0.057507
# 2025-04-03: Pending order cleared
# 2025-04-03: BUY EXECUTED (CLOSE SHORT), Price: 82812.00, Size: 0.057507, PnL: 103.93
# 2025-04-03: Pending order cleared
# 2025-04-03: Order Failed: Status=Canceled, Size=0.057507, Price=81164.00
# 2025-04-03: Pending order cleared due to failure
# Sizer: Position size: 0.056168, cash=1032.24, price=82700.00, margin_required=929.01
# 2025-04-03: TAIL → SELL ORDER PLACED: Price=82700.00, TP=81459.50, SL=83113.50
# 2025-04-03: SELL EXECUTED (OPEN SHORT), Price: 82700.00, Size: -0.056168
# 2025-04-03: Pending order cleared
# 2025-04-03: BUY EXECUTED (CLOSE SHORT), Price: 83113.50, Size: 0.056168, PnL: 116.13
# 2025-04-03: Pending order cleared
# 2025-04-03: Order Failed: Status=Canceled, Size=0.056168, Price=81459.50
# 2025-04-03: Pending order cleared due to failure
# Sizer: Position size: 0.054659, cash=1009.01, price=83069.69, margin_required=908.11
# 2025-04-03: HEAD → BUY ORDER PLACED: Price=83069.69, TP=84315.74, SL=82654.34
# 2025-04-03: BUY EXECUTED (OPEN LONG), Price: 83069.69, Size: 0.054659
# 2025-04-03: Pending order cleared
# 2025-04-04: SELL EXECUTED (CLOSE LONG), Price: 82654.34, Size: -0.054659, PnL: -113.51
# 2025-04-04: Pending order cleared
# 2025-04-04: Order Failed: Status=Canceled, Size=-0.054659, Price=84315.74
# 2025-04-04: Pending order cleared due to failure
# Sizer: Position size: 0.053766, cash=986.31, price=82550.00, margin_required=887.68
# 2025-04-04: HEAD → BUY ORDER PLACED: Price=82550.00, TP=83788.25, SL=82137.25
# 2025-04-04: BUY EXECUTED (OPEN LONG), Price: 82550.00, Size: 0.053766
# 2025-04-04: Pending order cleared
# 2025-04-04: SELL EXECUTED (CLOSE LONG), Price: 82137.25, Size: -0.053766, PnL: -110.96
# 2025-04-04: Pending order cleared
# 2025-04-04: Order Failed: Status=Canceled, Size=-0.053766, Price=83788.25
# 2025-04-04: Pending order cleared due to failure
# Sizer: Position size: 0.052531, cash=964.12, price=82590.00, margin_required=867.70
# 2025-04-04: TAIL → SELL ORDER PLACED: Price=82590.00, TP=81351.15, SL=83002.95
# 2025-04-04: SELL EXECUTED (OPEN SHORT), Price: 82600.06, Size: -0.052531
# 2025-04-04: Pending order cleared
# 2025-04-04: BUY EXECUTED (CLOSE SHORT), Price: 83068.00, Size: 0.052531, PnL: 122.91
# 2025-04-04: Pending order cleared
# 2025-04-04: Order Failed: Status=Canceled, Size=0.052531, Price=81351.15
# 2025-04-04: Pending order cleared due to failure
# Sizer: Position size: 0.050883, cash=939.53, price=83090.00, margin_required=845.58
# 2025-04-04: HEAD → BUY ORDER PLACED: Price=83090.00, TP=84336.35, SL=82674.55
# 2025-04-04: BUY EXECUTED (OPEN LONG), Price: 83097.00, Size: 0.050883
# 2025-04-04: Pending order cleared
# 2025-04-04: SELL EXECUTED (CLOSE LONG), Price: 82674.55, Size: -0.050883, PnL: -107.48
# 2025-04-04: Pending order cleared
# 2025-04-04: Order Failed: Status=Canceled, Size=-0.050883, Price=84336.35
# 2025-04-04: Pending order cleared due to failure
# Sizer: Position size: 0.049879, cash=918.04, price=82823.40, margin_required=826.23
# 2025-04-04: HEAD → BUY ORDER PLACED: Price=82823.40, TP=84065.75, SL=82409.28
# 2025-04-04: BUY EXECUTED (OPEN LONG), Price: 82619.00, Size: 0.049879
# 2025-04-04: Pending order cleared
# 2025-04-04: SELL EXECUTED (CLOSE LONG), Price: 82409.28, Size: -0.049879, PnL: -52.30
# 2025-04-04: Pending order cleared
# 2025-04-04: Order Failed: Status=Canceled, Size=-0.049879, Price=84065.75
# 2025-04-04: Pending order cleared due to failure
# Sizer: Position size: 0.049595, cash=907.58, price=82349.60, margin_required=816.82
# 2025-04-04: HEAD → BUY ORDER PLACED: Price=82349.60, TP=83584.84, SL=81937.85
# 2025-04-04: BUY EXECUTED (OPEN LONG), Price: 82246.68, Size: 0.049595
# 2025-04-04: Pending order cleared
# 2025-04-04: SELL EXECUTED (CLOSE LONG), Price: 81937.85, Size: -0.049595, PnL: -76.58
# 2025-04-04: Pending order cleared
# 2025-04-04: Order Failed: Status=Canceled, Size=-0.049595, Price=83584.84
# 2025-04-04: Pending order cleared due to failure
# Sizer: Position size: 0.048972, cash=892.26, price=81990.00, margin_required=803.04
# 2025-04-04: TAIL → SELL ORDER PLACED: Price=81990.00, TP=80760.15, SL=82399.95
# 2025-04-04: SELL EXECUTED (OPEN SHORT), Price: 81990.00, Size: -0.048972
# 2025-04-04: Pending order cleared
# 2025-04-04: BUY EXECUTED (CLOSE SHORT), Price: 82399.95, Size: 0.048972, PnL: 100.38
# 2025-04-04: Pending order cleared
# 2025-04-04: Order Failed: Status=Canceled, Size=0.048972, Price=80760.15
# 2025-04-04: Pending order cleared due to failure
# Sizer: Position size: 0.047705, cash=872.19, price=82273.47, margin_required=784.97
# 2025-04-04: TAIL → SELL ORDER PLACED: Price=82273.47, TP=81039.37, SL=82684.84
# 2025-04-04: SELL EXECUTED (OPEN SHORT), Price: 82273.50, Size: -0.047705
# 2025-04-04: Pending order cleared
# 2025-04-04: BUY EXECUTED (CLOSE SHORT), Price: 82684.84, Size: 0.047705, PnL: 98.11
# 2025-04-04: Pending order cleared
# 2025-04-04: Order Failed: Status=Canceled, Size=0.047705, Price=81039.37
# 2025-04-04: Pending order cleared due to failure
# Sizer: Position size: 0.046369, cash=852.56, price=82740.00, margin_required=767.31
# 2025-04-04: TAIL → SELL ORDER PLACED: Price=82740.00, TP=81498.90, SL=83153.70
# 2025-04-04: SELL EXECUTED (OPEN SHORT), Price: 82740.00, Size: -0.046369
# 2025-04-04: Pending order cleared
# 2025-04-04: BUY EXECUTED (CLOSE SHORT), Price: 83153.70, Size: 0.046369, PnL: 95.91
# 2025-04-04: Pending order cleared
# 2025-04-04: Order Failed: Status=Canceled, Size=0.046369, Price=81498.90
# 2025-04-04: Pending order cleared due to failure
# Sizer: Position size: 0.045075, cash=833.38, price=83199.00, margin_required=750.04
# 2025-04-04: TAIL → SELL ORDER PLACED: Price=83199.00, TP=81951.01, SL=83614.99
# 2025-04-04: SELL EXECUTED (OPEN SHORT), Price: 83055.07, Size: -0.045075
# 2025-04-04: Pending order cleared
# 2025-04-04: BUY EXECUTED (CLOSE SHORT), Price: 83614.99, Size: 0.045075, PnL: 126.19
# 2025-04-04: Pending order cleared
# 2025-04-04: Order Failed: Status=Canceled, Size=0.045075, Price=81951.01
# 2025-04-04: Pending order cleared due to failure
# Sizer: Position size: 0.043472, cash=808.14, price=83654.00, margin_required=727.33
# 2025-04-04: HEAD → BUY ORDER PLACED: Price=83654.00, TP=84908.81, SL=83235.73
# 2025-04-04: BUY EXECUTED (OPEN LONG), Price: 83670.00, Size: 0.043472
# 2025-04-04: Pending order cleared
# 2025-04-04: SELL EXECUTED (CLOSE LONG), Price: 83235.73, Size: -0.043472, PnL: -94.39
# 2025-04-04: Pending order cleared
# 2025-04-04: Order Failed: Status=Canceled, Size=-0.043472, Price=84908.81
# 2025-04-04: Pending order cleared due to failure
# Sizer: Position size: 0.042683, cash=789.26, price=83210.00, margin_required=710.34
# 2025-04-04: TAIL → SELL ORDER PLACED: Price=83210.00, TP=81961.85, SL=83626.05
# 2025-04-04: SELL EXECUTED (OPEN SHORT), Price: 83210.00, Size: -0.042683
# 2025-04-04: Pending order cleared
# 2025-04-04: BUY EXECUTED (CLOSE SHORT), Price: 83626.05, Size: 0.042683, PnL: 88.79
# 2025-04-04: Pending order cleared
# 2025-04-04: Order Failed: Status=Canceled, Size=0.042683, Price=81961.85
# 2025-04-04: Pending order cleared due to failure
# Sizer: Position size: 0.041484, cash=771.50, price=83690.00, margin_required=694.35
# 2025-04-04: HEAD → BUY ORDER PLACED: Price=83690.00, TP=84945.35, SL=83271.55
# 2025-04-04: BUY EXECUTED (OPEN LONG), Price: 83690.00, Size: 0.041484
# 2025-04-04: Pending order cleared
# 2025-04-04: SELL EXECUTED (CLOSE LONG), Price: 83271.55, Size: -0.041484, PnL: -86.79
# 2025-04-04: Pending order cleared
# 2025-04-04: Order Failed: Status=Canceled, Size=-0.041484, Price=84945.35
# 2025-04-04: Pending order cleared due to failure
# Sizer: Position size: 0.040770, cash=754.14, price=83238.00, margin_required=678.73
# 2025-04-04: HEAD → BUY ORDER PLACED: Price=83238.00, TP=84486.57, SL=82821.81
# 2025-04-04: BUY EXECUTED (OPEN LONG), Price: 83238.00, Size: 0.040770
# 2025-04-04: Pending order cleared
# 2025-04-05: SELL EXECUTED (CLOSE LONG), Price: 82808.45, Size: -0.040770, PnL: -87.56
# 2025-04-05: Pending order cleared
# 2025-04-05: Order Failed: Status=Canceled, Size=-0.040770, Price=84486.57
# 2025-04-05: Pending order cleared due to failure
# Sizer: Position size: 0.040030, cash=736.63, price=82808.45, margin_required=662.97
# 2025-04-05: TAIL → SELL ORDER PLACED: Price=82808.45, TP=81566.32, SL=83222.49
# 2025-04-05: SELL EXECUTED (OPEN SHORT), Price: 82808.45, Size: -0.040030
# 2025-04-05: Pending order cleared
# 2025-04-05: BUY EXECUTED (CLOSE SHORT), Price: 83222.49, Size: 0.040030, PnL: 82.87
# 2025-04-05: Pending order cleared
# 2025-04-05: Order Failed: Status=Canceled, Size=0.040030, Price=81566.32
# 2025-04-05: Pending order cleared due to failure
# Sizer: Position size: 0.038899, cash=720.06, price=83300.00, margin_required=648.05
# 2025-04-05: TAIL → SELL ORDER PLACED: Price=83300.00, TP=82050.50, SL=83716.50
# 2025-04-05: SELL EXECUTED (OPEN SHORT), Price: 83300.00, Size: -0.038899
# 2025-04-05: Pending order cleared
# 2025-04-06: BUY EXECUTED (CLOSE SHORT), Price: 82050.50, Size: 0.038899, PnL: -243.02
# 2025-04-06: Pending order cleared
# 2025-04-06: Order Failed: Status=Canceled, Size=0.038899, Price=83716.50
# 2025-04-06: Pending order cleared due to failure
# Sizer: Position size: 0.042172, cash=768.66, price=82021.00, margin_required=691.80
# 2025-04-06: TAIL → SELL ORDER PLACED: Price=82021.00, TP=80790.68, SL=82431.10
# 2025-04-06: SELL EXECUTED (OPEN SHORT), Price: 82021.00, Size: -0.042172
# 2025-04-06: Pending order cleared
# 2025-04-06: BUY EXECUTED (CLOSE SHORT), Price: 80790.68, Size: 0.042172, PnL: -259.42
# 2025-04-06: Pending order cleared
# 2025-04-06: Order Failed: Status=Canceled, Size=0.042172, Price=82431.10
# 2025-04-06: Pending order cleared due to failure
# Sizer: Position size: 0.045699, cash=820.55, price=80800.00, margin_required=738.49
# 2025-04-06: HEAD → BUY ORDER PLACED: Price=80800.00, TP=82012.00, SL=80396.00
# 2025-04-06: BUY EXECUTED (OPEN LONG), Price: 80753.13, Size: 0.045699
# 2025-04-06: Pending order cleared
# 2025-04-06: SELL EXECUTED (CLOSE LONG), Price: 80396.00, Size: -0.045699, PnL: -81.60
# 2025-04-06: Pending order cleared
# 2025-04-06: Order Failed: Status=Canceled, Size=-0.045699, Price=82012.00
# 2025-04-06: Pending order cleared due to failure
# Sizer: Position size: 0.045024, cash=804.23, price=80380.00, margin_required=723.80
# 2025-04-06: HEAD → BUY ORDER PLACED: Price=80380.00, TP=81585.70, SL=79978.10
# 2025-04-06: BUY EXECUTED (OPEN LONG), Price: 80400.00, Size: 0.045024
# 2025-04-06: Pending order cleared
# 2025-04-06: SELL EXECUTED (CLOSE LONG), Price: 79978.10, Size: -0.045024, PnL: -94.98
# 2025-04-06: Pending order cleared
# 2025-04-06: Order Failed: Status=Canceled, Size=-0.045024, Price=81585.70
# 2025-04-06: Pending order cleared due to failure
# Sizer: Position size: 0.044208, cash=785.23, price=79930.00, margin_required=706.71
# 2025-04-06: HEAD → BUY ORDER PLACED: Price=79930.00, TP=81128.95, SL=79530.35
# 2025-04-06: BUY EXECUTED (OPEN LONG), Price: 79930.00, Size: 0.044208
# 2025-04-06: Pending order cleared
# 2025-04-06: SELL EXECUTED (CLOSE LONG), Price: 79530.35, Size: -0.044208, PnL: -88.34
# 2025-04-06: Pending order cleared
# 2025-04-06: Order Failed: Status=Canceled, Size=-0.044208, Price=81128.95
# 2025-04-06: Pending order cleared due to failure
# Sizer: Position size: 0.043433, cash=767.56, price=79525.00, margin_required=690.81
# 2025-04-06: HEAD → BUY ORDER PLACED: Price=79525.00, TP=80717.87, SL=79127.38
# 2025-04-06: BUY EXECUTED (OPEN LONG), Price: 79524.00, Size: 0.043433
# 2025-04-06: Pending order cleared
# 2025-04-06: SELL EXECUTED (CLOSE LONG), Price: 79127.38, Size: -0.043433, PnL: -86.13
# 2025-04-06: Pending order cleared
# 2025-04-06: Order Failed: Status=Canceled, Size=-0.043433, Price=80717.87
# 2025-04-06: Pending order cleared due to failure
# Sizer: Position size: 0.042687, cash=750.34, price=79100.00, margin_required=675.30
# 2025-04-06: HEAD → BUY ORDER PLACED: Price=79100.00, TP=80286.50, SL=78704.50
# 2025-04-06: BUY EXECUTED (OPEN LONG), Price: 79172.00, Size: 0.042687
# 2025-04-06: Pending order cleared
# 2025-04-06: SELL EXECUTED (CLOSE LONG), Price: 78704.50, Size: -0.042687, PnL: -99.78
# 2025-04-06: Pending order cleared
# 2025-04-06: Order Failed: Status=Canceled, Size=-0.042687, Price=80286.50
# 2025-04-06: Pending order cleared due to failure
# Sizer: Position size: 0.041789, cash=730.38, price=78650.00, margin_required=657.34
# 2025-04-06: TAIL → SELL ORDER PLACED: Price=78650.00, TP=77470.25, SL=79043.25
# 2025-04-06: SELL EXECUTED (OPEN SHORT), Price: 78650.00, Size: -0.041789
# 2025-04-06: Pending order cleared
# 2025-04-06: BUY EXECUTED (CLOSE SHORT), Price: 79043.25, Size: 0.041789, PnL: 82.17
# 2025-04-06: Pending order cleared
# 2025-04-06: Order Failed: Status=Canceled, Size=0.041789, Price=77470.25
# 2025-04-06: Pending order cleared due to failure
# Sizer: Position size: 0.040668, cash=713.95, price=79000.02, margin_required=642.55
# 2025-04-06: HEAD → BUY ORDER PLACED: Price=79000.02, TP=80185.02, SL=78605.02
# 2025-04-06: BUY EXECUTED (OPEN LONG), Price: 79154.91, Size: 0.040668
# 2025-04-06: Pending order cleared
# 2025-04-06: SELL EXECUTED (CLOSE LONG), Price: 78605.02, Size: -0.040668, PnL: -111.81
# 2025-04-06: Pending order cleared
# 2025-04-06: Order Failed: Status=Canceled, Size=-0.040668, Price=80185.02
# 2025-04-06: Pending order cleared due to failure
# Sizer: Position size: 0.039584, cash=691.58, price=78621.00, margin_required=622.42
# 2025-04-06: HEAD → BUY ORDER PLACED: Price=78621.00, TP=79800.31, SL=78227.90
# 2025-04-06: BUY EXECUTED (OPEN LONG), Price: 78631.77, Size: 0.039584
# 2025-04-06: Pending order cleared
# 2025-04-06: SELL EXECUTED (CLOSE LONG), Price: 78227.90, Size: -0.039584, PnL: -79.93
# 2025-04-06: Pending order cleared
# 2025-04-06: Order Failed: Status=Canceled, Size=-0.039584, Price=79800.31
# 2025-04-06: Pending order cleared due to failure
# Sizer: Position size: 0.038877, cash=675.60, price=78200.00, margin_required=608.04
# 2025-04-06: HEAD → BUY ORDER PLACED: Price=78200.00, TP=79373.00, SL=77809.00
# 2025-04-06: BUY EXECUTED (OPEN LONG), Price: 78323.00, Size: 0.038877
# 2025-04-06: Pending order cleared
# 2025-04-06: SELL EXECUTED (CLOSE LONG), Price: 77809.00, Size: -0.038877, PnL: -99.91
# 2025-04-06: Pending order cleared
# 2025-04-06: Order Failed: Status=Canceled, Size=-0.038877, Price=79373.00
# 2025-04-06: Pending order cleared due to failure
# Sizer: Position size: 0.037992, cash=655.61, price=77655.00, margin_required=590.05
# 2025-04-06: TAIL → SELL ORDER PLACED: Price=77655.00, TP=76490.18, SL=78043.27
# 2025-04-06: SELL EXECUTED (OPEN SHORT), Price: 77655.00, Size: -0.037992
# 2025-04-06: Pending order cleared
# 2025-04-06: BUY EXECUTED (CLOSE SHORT), Price: 78100.00, Size: 0.037992, PnL: 84.53
# 2025-04-06: Pending order cleared
# 2025-04-06: Order Failed: Status=Canceled, Size=0.037992, Price=76490.18
# 2025-04-06: Pending order cleared due to failure
# Sizer: Position size: 0.036801, cash=638.71, price=78100.00, margin_required=574.84
# 2025-04-06: HEAD → BUY ORDER PLACED: Price=78100.00, TP=79271.50, SL=77709.50
# 2025-04-06: BUY EXECUTED (OPEN LONG), Price: 78100.00, Size: 0.036801
# 2025-04-06: Pending order cleared
# 2025-04-07: SELL EXECUTED (CLOSE LONG), Price: 77709.50, Size: -0.036801, PnL: -71.85
# 2025-04-07: Pending order cleared
# 2025-04-07: Order Failed: Status=Canceled, Size=-0.036801, Price=79271.50
# 2025-04-07: Pending order cleared due to failure
# Sizer: Position size: 0.036158, cash=624.34, price=77700.00, margin_required=561.90
# 2025-04-07: TAIL → SELL ORDER PLACED: Price=77700.00, TP=76534.50, SL=78088.50
# 2025-04-07: SELL EXECUTED (OPEN SHORT), Price: 77700.00, Size: -0.036158
# 2025-04-07: Pending order cleared
# 2025-04-07: BUY EXECUTED (CLOSE SHORT), Price: 78097.97, Size: 0.036158, PnL: 71.95
# 2025-04-07: Pending order cleared
# 2025-04-07: Order Failed: Status=Canceled, Size=0.036158, Price=76534.50
# 2025-04-07: Pending order cleared due to failure
# Sizer: Position size: 0.035145, cash=609.95, price=78097.97, margin_required=548.95
# 2025-04-07: HEAD → BUY ORDER PLACED: Price=78097.97, TP=79269.44, SL=77707.48
# 2025-04-07: BUY EXECUTED (OPEN LONG), Price: 78000.00, Size: 0.035145
# 2025-04-07: Pending order cleared
# 2025-04-07: SELL EXECUTED (CLOSE LONG), Price: 77707.48, Size: -0.035145, PnL: -51.40
# 2025-04-07: Pending order cleared
# 2025-04-07: Order Failed: Status=Canceled, Size=-0.035145, Price=79269.44
# 2025-04-07: Pending order cleared due to failure
# Sizer: Position size: 0.034799, cash=599.66, price=77544.07, margin_required=539.70
# 2025-04-07: TAIL → SELL ORDER PLACED: Price=77544.07, TP=76380.91, SL=77931.79
# 2025-04-07: SELL EXECUTED (OPEN SHORT), Price: 77554.65, Size: -0.034799
# 2025-04-07: Pending order cleared
# 2025-04-07: BUY EXECUTED (CLOSE SHORT), Price: 77931.79, Size: 0.034799, PnL: 65.62
# 2025-04-07: Pending order cleared
# 2025-04-07: Order Failed: Status=Canceled, Size=0.034799, Price=76380.91
# 2025-04-07: Pending order cleared due to failure
# Sizer: Position size: 0.033839, cash=586.54, price=78000.00, margin_required=527.89
# 2025-04-07: HEAD → BUY ORDER PLACED: Price=78000.00, TP=79170.00, SL=77610.00
# 2025-04-07: BUY EXECUTED (OPEN LONG), Price: 78093.97, Size: 0.033839
# 2025-04-07: Pending order cleared
# 2025-04-07: SELL EXECUTED (CLOSE LONG), Price: 77610.00, Size: -0.033839, PnL: -81.88
# 2025-04-07: Pending order cleared
# 2025-04-07: Order Failed: Status=Canceled, Size=-0.033839, Price=79170.00
# 2025-04-07: Pending order cleared due to failure
# Sizer: Position size: 0.033063, cash=570.16, price=77601.07, margin_required=513.15
# 2025-04-07: HEAD → BUY ORDER PLACED: Price=77601.07, TP=78765.09, SL=77213.06
# 2025-04-07: BUY EXECUTED (OPEN LONG), Price: 77601.07, Size: 0.033063
# 2025-04-07: Pending order cleared
# 2025-04-07: SELL EXECUTED (CLOSE LONG), Price: 78765.09, Size: -0.033063, PnL: 192.43
# 2025-04-07: Pending order cleared
# 2025-04-07: Order Failed: Status=Canceled, Size=-0.033063, Price=77213.06
# 2025-04-07: Pending order cleared due to failure
# Sizer: Position size: 0.034758, cash=608.65, price=78800.00, margin_required=547.78
# 2025-04-07: TAIL → SELL ORDER PLACED: Price=78800.00, TP=77618.00, SL=79194.00
# 2025-04-07: SELL EXECUTED (OPEN SHORT), Price: 78695.78, Size: -0.034758
# 2025-04-07: Pending order cleared
# 2025-04-07: BUY EXECUTED (CLOSE SHORT), Price: 79194.00, Size: 0.034758, PnL: 86.59
# 2025-04-07: Pending order cleared
# 2025-04-07: Order Failed: Status=Canceled, Size=0.034758, Price=77618.00
# 2025-04-07: Pending order cleared due to failure
# Sizer: Position size: 0.033577, cash=591.33, price=79250.00, margin_required=532.20
# 2025-04-07: HEAD → BUY ORDER PLACED: Price=79250.00, TP=80438.75, SL=78853.75
# 2025-04-07: BUY EXECUTED (OPEN LONG), Price: 79348.83, Size: 0.033577
# 2025-04-07: Pending order cleared
# 2025-04-07: SELL EXECUTED (CLOSE LONG), Price: 78853.75, Size: -0.033577, PnL: -83.12
# 2025-04-07: Pending order cleared
# 2025-04-07: Order Failed: Status=Canceled, Size=-0.033577, Price=80438.75
# 2025-04-07: Pending order cleared due to failure
# Sizer: Position size: 0.032737, cash=574.71, price=78999.78, margin_required=517.24
# 2025-04-07: TAIL → SELL ORDER PLACED: Price=78999.78, TP=77814.78, SL=79394.78
# 2025-04-07: SELL EXECUTED (OPEN SHORT), Price: 78899.91, Size: -0.032737
# 2025-04-07: Pending order cleared
# 2025-04-07: BUY EXECUTED (CLOSE SHORT), Price: 79394.78, Size: 0.032737, PnL: 81.00
# 2025-04-07: Pending order cleared
# 2025-04-07: Order Failed: Status=Canceled, Size=0.032737, Price=77814.78
# 2025-04-07: Pending order cleared due to failure
# Sizer: Position size: 0.032027, cash=558.51, price=78472.82, margin_required=502.66
# 2025-04-07: HEAD → BUY ORDER PLACED: Price=78472.82, TP=79649.91, SL=78080.46
# 2025-04-07: BUY EXECUTED (OPEN LONG), Price: 78376.92, Size: 0.032027
# 2025-04-07: Pending order cleared
# 2025-04-07: SELL EXECUTED (CLOSE LONG), Price: 78080.46, Size: -0.032027, PnL: -47.47
# 2025-04-07: Pending order cleared
# 2025-04-07: Order Failed: Status=Canceled, Size=-0.032027, Price=79649.91
# 2025-04-07: Pending order cleared due to failure
# Sizer: Position size: 0.031593, cash=549.01, price=78199.99, margin_required=494.11
# 2025-04-07: HEAD → BUY ORDER PLACED: Price=78199.99, TP=79372.99, SL=77808.99
# 2025-04-07: BUY EXECUTED (OPEN LONG), Price: 78199.99, Size: 0.031593
# 2025-04-07: Pending order cleared
# 2025-04-07: SELL EXECUTED (CLOSE LONG), Price: 77800.03, Size: -0.031593, PnL: -63.18
# 2025-04-07: Pending order cleared
# 2025-04-07: Order Failed: Status=Canceled, Size=-0.031593, Price=79372.99
# 2025-04-07: Pending order cleared due to failure
# Sizer: Position size: 0.031024, cash=536.38, price=77801.00, margin_required=482.74
# 2025-04-07: HEAD → BUY ORDER PLACED: Price=77801.00, TP=78968.01, SL=77411.99
# 2025-04-07: BUY EXECUTED (OPEN LONG), Price: 77700.00, Size: 0.031024
# 2025-04-07: Pending order cleared
# 2025-04-07: SELL EXECUTED (CLOSE LONG), Price: 77400.01, Size: -0.031024, PnL: -46.53
# 2025-04-07: Pending order cleared
# 2025-04-07: Order Failed: Status=Canceled, Size=-0.031024, Price=78968.01
# 2025-04-07: Pending order cleared due to failure
# Sizer: Position size: 0.030565, cash=527.07, price=77600.00, margin_required=474.36
# 2025-04-07: TAIL → SELL ORDER PLACED: Price=77600.00, TP=76436.00, SL=77988.00
# 2025-04-07: SELL EXECUTED (OPEN SHORT), Price: 77600.00, Size: -0.030565
# 2025-04-07: Pending order cleared
# 2025-04-07: BUY EXECUTED (CLOSE SHORT), Price: 77988.00, Size: 0.030565, PnL: 59.30
# 2025-04-07: Pending order cleared
# ...
# 2025-04-21: HEAD → BUY ORDER PLACED: Price=87575.95, TP=88889.59, SL=87138.07
# 2025-04-21: BUY EXECUTED (OPEN LONG), Price: 87545.00, Size: 0.011431
# 2025-04-21: Pending order cleared
# 2025-04-21: SELL EXECUTED (CLOSE LONG), Price: 87138.07, Size: -0.011431, PnL: -23.26
# 2025-04-21: Pending order cleared
# 2025-04-21: Order Failed: Status=Canceled, Size=-0.011431, Price=88889.59
# 2025-04-21: Pending order cleared due to failure
# Sizer: Position size: 0.011176, cash=217.81, price=87698.00, margin_required=196.02
# 2025-04-21: TAIL → SELL ORDER PLACED: Price=87698.00, TP=86382.53, SL=88136.49
# 2025-04-21: SELL EXECUTED (OPEN SHORT), Price: 87697.99, Size: -0.011176
# 2025-04-21: Pending order cleared
# 2025-04-21: BUY EXECUTED (CLOSE SHORT), Price: 86382.53, Size: 0.011176, PnL: -73.51
# 2025-04-21: Pending order cleared
# 2025-04-21: Order Failed: Status=Canceled, Size=0.011176, Price=88136.49
# 2025-04-21: Pending order cleared due to failure
# Sizer: Position size: 0.012096, cash=232.51, price=86501.00, margin_required=209.26
# 2025-04-21: HEAD → BUY ORDER PLACED: Price=86501.00, TP=87798.51, SL=86068.49
# 2025-04-21: BUY EXECUTED (OPEN LONG), Price: 86500.98, Size: 0.012096
# 2025-04-21: Pending order cleared
# 2025-04-22: SELL EXECUTED (CLOSE LONG), Price: 87798.51, Size: -0.012096, PnL: 78.47
# 2025-04-22: Pending order cleared
# 2025-04-22: Order Failed: Status=Canceled, Size=-0.012096, Price=86068.49
# 2025-04-22: Pending order cleared due to failure
# Sizer: Position size: 0.012711, cash=248.20, price=87870.00, margin_required=223.38
# 2025-04-22: TAIL → SELL ORDER PLACED: Price=87870.00, TP=86551.95, SL=88309.35
# 2025-04-22: SELL EXECUTED (OPEN SHORT), Price: 87870.00, Size: -0.012711
# 2025-04-22: Pending order cleared
# 2025-04-22: BUY EXECUTED (CLOSE SHORT), Price: 88309.35, Size: 0.012711, PnL: 27.92
# 2025-04-22: Pending order cleared
# 2025-04-22: Order Failed: Status=Canceled, Size=0.012711, Price=86551.95
# 2025-04-22: Pending order cleared due to failure
# Sizer: Position size: 0.012361, cash=242.62, price=88326.00, margin_required=218.36
# 2025-04-22: HEAD → BUY ORDER PLACED: Price=88326.00, TP=89650.89, SL=87884.37
# 2025-04-22: BUY EXECUTED (OPEN LONG), Price: 88327.00, Size: 0.012361
# 2025-04-22: Pending order cleared
# 2025-04-22: SELL EXECUTED (CLOSE LONG), Price: 89650.89, Size: -0.012361, PnL: 81.82
# 2025-04-22: Pending order cleared
# 2025-04-22: Order Failed: Status=Canceled, Size=-0.012361, Price=87884.37
# 2025-04-22: Pending order cleared due to failure
# Sizer: Position size: 0.012992, cash=258.98, price=89701.00, margin_required=233.08
# 2025-04-22: TAIL → SELL ORDER PLACED: Price=89701.00, TP=88355.49, SL=90149.50
# 2025-04-22: SELL EXECUTED (OPEN SHORT), Price: 89712.00, Size: -0.012992
# 2025-04-22: Pending order cleared
# 2025-04-22: BUY EXECUTED (CLOSE SHORT), Price: 90149.50, Size: 0.012992, PnL: 28.42
# 2025-04-22: Pending order cleared
# 2025-04-22: Order Failed: Status=Canceled, Size=0.012992, Price=88355.49
# 2025-04-22: Pending order cleared due to failure
# Sizer: Position size: 0.012623, cash=253.30, price=90299.00, margin_required=227.97
# 2025-04-22: HEAD → BUY ORDER PLACED: Price=90299.00, TP=91653.48, SL=89847.51
# 2025-04-22: BUY EXECUTED (OPEN LONG), Price: 90299.00, Size: 0.012623
# 2025-04-22: Pending order cleared
# 2025-04-22: SELL EXECUTED (CLOSE LONG), Price: 89847.51, Size: -0.012623, PnL: -28.50
# 2025-04-22: Pending order cleared
# 2025-04-22: Order Failed: Status=Canceled, Size=-0.012623, Price=91653.48
# 2025-04-22: Pending order cleared due to failure
# Sizer: Position size: 0.012413, cash=247.60, price=89760.00, margin_required=222.84
# 2025-04-22: TAIL → SELL ORDER PLACED: Price=89760.00, TP=88413.60, SL=90208.80
# 2025-04-22: SELL EXECUTED (OPEN SHORT), Price: 89760.00, Size: -0.012413
# 2025-04-22: Pending order cleared
# 2025-04-22: BUY EXECUTED (CLOSE SHORT), Price: 90208.80, Size: 0.012413, PnL: 27.85
# 2025-04-22: Pending order cleared
# 2025-04-22: Order Failed: Status=Canceled, Size=0.012413, Price=88413.60
# 2025-04-22: Pending order cleared due to failure
# Sizer: Position size: 0.012128, cash=242.03, price=89800.01, margin_required=217.82
# 2025-04-22: HEAD → BUY ORDER PLACED: Price=89800.01, TP=91147.01, SL=89351.01
# 2025-04-22: BUY EXECUTED (OPEN LONG), Price: 89800.01, Size: 0.012128
# 2025-04-22: Pending order cleared
# 2025-04-22: SELL EXECUTED (CLOSE LONG), Price: 89351.01, Size: -0.012128, PnL: -27.23
# 2025-04-22: Pending order cleared
# 2025-04-22: Order Failed: Status=Canceled, Size=-0.012128, Price=91147.01
# 2025-04-22: Pending order cleared due to failure
# Sizer: Position size: 0.011813, cash=236.58, price=90124.99, margin_required=212.92
# 2025-04-22: TAIL → SELL ORDER PLACED: Price=90124.99, TP=88773.12, SL=90575.61
# 2025-04-22: SELL EXECUTED (OPEN SHORT), Price: 90124.00, Size: -0.011813
# 2025-04-22: Pending order cleared
# 2025-04-22: BUY EXECUTED (CLOSE SHORT), Price: 90575.61, Size: 0.011813, PnL: 26.67
# 2025-04-22: Pending order cleared
# 2025-04-22: Order Failed: Status=Canceled, Size=0.011813, Price=88773.12
# 2025-04-22: Pending order cleared due to failure
# Sizer: Position size: 0.011486, cash=231.25, price=90600.00, margin_required=208.12
# 2025-04-22: TAIL → SELL ORDER PLACED: Price=90600.00, TP=89241.00, SL=91053.00
# 2025-04-22: SELL EXECUTED (OPEN SHORT), Price: 90600.00, Size: -0.011486
# 2025-04-22: Pending order cleared
# 2025-04-22: BUY EXECUTED (CLOSE SHORT), Price: 89241.00, Size: 0.011486, PnL: -78.05
# 2025-04-22: Pending order cleared
# 2025-04-22: Order Failed: Status=Canceled, Size=0.011486, Price=91053.00
# 2025-04-22: Pending order cleared due to failure
# Sizer: Position size: 0.012363, cash=246.86, price=89850.00, margin_required=222.17
# 2025-04-22: TAIL → SELL ORDER PLACED: Price=89850.00, TP=88502.25, SL=90299.25
# 2025-04-22: SELL EXECUTED (OPEN SHORT), Price: 90739.00, Size: -0.012363
# 2025-04-22: Pending order cleared
# 2025-04-22: BUY EXECUTED (CLOSE SHORT), Price: 90693.60, Size: 0.012363, PnL: -2.81
# 2025-04-22: Pending order cleared
# 2025-04-22: Order Failed: Status=Canceled, Size=0.012363, Price=88502.25
# 2025-04-22: Pending order cleared due to failure
# Sizer: Position size: 0.012276, cash=247.42, price=90693.70, margin_required=222.68
# 2025-04-22: HEAD → BUY ORDER PLACED: Price=90693.70, TP=92054.11, SL=90240.23
# 2025-04-22: BUY EXECUTED (OPEN LONG), Price: 90699.99, Size: 0.012276
# 2025-04-22: Pending order cleared
# 2025-04-22: SELL EXECUTED (CLOSE LONG), Price: 92054.11, Size: -0.012276, PnL: 83.12
# 2025-04-22: Pending order cleared
# 2025-04-22: Order Failed: Status=Canceled, Size=-0.012276, Price=90240.23
# 2025-04-22: Pending order cleared due to failure
# Sizer: Position size: 0.012894, cash=264.04, price=92150.00, margin_required=237.64
# 2025-04-22: TAIL → SELL ORDER PLACED: Price=92150.00, TP=90767.75, SL=92610.75
# 2025-04-22: SELL EXECUTED (OPEN SHORT), Price: 92150.00, Size: -0.012894
# 2025-04-22: Pending order cleared
# 2025-04-22: BUY EXECUTED (CLOSE SHORT), Price: 92610.75, Size: 0.012894, PnL: 29.70
# 2025-04-22: Pending order cleared
# 2025-04-22: Order Failed: Status=Canceled, Size=0.012894, Price=90767.75
# 2025-04-22: Pending order cleared due to failure
# Sizer: Position size: 0.012543, cash=258.10, price=92600.00, margin_required=232.29
# 2025-04-22: HEAD → BUY ORDER PLACED: Price=92600.00, TP=93989.00, SL=92137.00
# 2025-04-22: BUY EXECUTED (OPEN LONG), Price: 92600.00, Size: 0.012543
# 2025-04-22: Pending order cleared
# 2025-04-23: SELL EXECUTED (CLOSE LONG), Price: 92137.00, Size: -0.012543, PnL: -29.04
# 2025-04-23: Pending order cleared
# 2025-04-23: Order Failed: Status=Canceled, Size=-0.012543, Price=93989.00
# 2025-04-23: Pending order cleared due to failure
# Sizer: Position size: 0.012325, cash=252.29, price=92115.82, margin_required=227.06
# 2025-04-23: HEAD → BUY ORDER PLACED: Price=92115.82, TP=93497.56, SL=91655.24
# 2025-04-23: BUY EXECUTED (OPEN LONG), Price: 92115.82, Size: 0.012325
# 2025-04-23: Pending order cleared
# 2025-04-23: SELL EXECUTED (CLOSE LONG), Price: 93497.56, Size: -0.012325, PnL: 85.15
# 2025-04-23: Pending order cleared
# 2025-04-23: Order Failed: Status=Canceled, Size=-0.012325, Price=91655.24
# 2025-04-23: Pending order cleared due to failure
# Sizer: Position size: 0.012962, cash=269.32, price=93500.00, margin_required=242.39
# 2025-04-23: TAIL → SELL ORDER PLACED: Price=93500.00, TP=92097.50, SL=93967.50
# 2025-04-23: SELL EXECUTED (OPEN SHORT), Price: 93459.97, Size: -0.012962
# 2025-04-23: Pending order cleared
# 2025-04-23: BUY EXECUTED (CLOSE SHORT), Price: 93967.50, Size: 0.012962, PnL: 32.89
# 2025-04-23: Pending order cleared
# 2025-04-23: Order Failed: Status=Canceled, Size=0.012962, Price=92097.50
# 2025-04-23: Pending order cleared due to failure
# Sizer: Position size: 0.012578, cash=262.74, price=94000.00, margin_required=236.47
# 2025-04-23: HEAD → BUY ORDER PLACED: Price=94000.00, TP=95410.00, SL=93530.00
# 2025-04-23: BUY EXECUTED (OPEN LONG), Price: 93998.00, Size: 0.012578
# 2025-04-23: Pending order cleared
# 2025-04-23: SELL EXECUTED (CLOSE LONG), Price: 93500.00, Size: -0.012578, PnL: -31.32
# 2025-04-23: Pending order cleared
# 2025-04-23: Order Failed: Status=Canceled, Size=-0.012578, Price=95410.00
# 2025-04-23: Pending order cleared due to failure
# Sizer: Position size: 0.012344, cash=256.48, price=93500.00, margin_required=230.83
# 2025-04-23: TAIL → SELL ORDER PLACED: Price=93500.00, TP=92097.50, SL=93967.50
# 2025-04-23: SELL EXECUTED (OPEN SHORT), Price: 93500.00, Size: -0.012344
# 2025-04-23: Pending order cleared
# 2025-04-23: BUY EXECUTED (CLOSE SHORT), Price: 92097.50, Size: 0.012344, PnL: -86.56
# 2025-04-23: Pending order cleared
# 2025-04-23: Order Failed: Status=Canceled, Size=0.012344, Price=93967.50
# 2025-04-23: Pending order cleared due to failure
# Sizer: Position size: 0.013407, cash=273.79, price=91900.00, margin_required=246.41
# 2025-04-23: TAIL → SELL ORDER PLACED: Price=91900.00, TP=90521.50, SL=92359.50
# 2025-04-23: SELL EXECUTED (OPEN SHORT), Price: 91938.37, Size: -0.013407
# 2025-04-23: Pending order cleared
# 2025-04-23: BUY EXECUTED (CLOSE SHORT), Price: 92359.50, Size: 0.013407, PnL: 28.23
# 2025-04-23: Pending order cleared
# 2025-04-23: Order Failed: Status=Canceled, Size=0.013407, Price=90521.50
# 2025-04-23: Pending order cleared due to failure
# Sizer: Position size: 0.013070, cash=268.15, price=92322.78, margin_required=241.33
# 2025-04-23: HEAD → BUY ORDER PLACED: Price=92322.78, TP=93707.62, SL=91861.17
# 2025-04-23: BUY EXECUTED (OPEN LONG), Price: 92322.78, Size: 0.013070
# 2025-04-23: Pending order cleared
# 2025-04-23: SELL EXECUTED (CLOSE LONG), Price: 93707.62, Size: -0.013070, PnL: 90.50
# 2025-04-23: Pending order cleared
# 2025-04-23: Order Failed: Status=Canceled, Size=-0.013070, Price=91861.17
# 2025-04-23: Pending order cleared due to failure
# Sizer: Position size: 0.013809, cash=286.25, price=93277.49, margin_required=257.62
# 2025-04-23: HEAD → BUY ORDER PLACED: Price=93277.49, TP=94676.65, SL=92811.10
# 2025-04-23: BUY EXECUTED (OPEN LONG), Price: 93277.46, Size: 0.013809
# 2025-04-23: Pending order cleared
# 2025-04-23: SELL EXECUTED (CLOSE LONG), Price: 92811.10, Size: -0.013809, PnL: -32.20
# 2025-04-23: Pending order cleared
# 2025-04-23: Order Failed: Status=Canceled, Size=-0.013809, Price=94676.65
# 2025-04-23: Pending order cleared due to failure
# Sizer: Position size: 0.013531, cash=279.81, price=93054.02, margin_required=251.82
# 2025-04-23: HEAD → BUY ORDER PLACED: Price=93054.02, TP=94449.83, SL=92588.75
# 2025-04-23: BUY EXECUTED (OPEN LONG), Price: 93054.02, Size: 0.013531
# 2025-04-23: Pending order cleared
# 2025-04-23: SELL EXECUTED (CLOSE LONG), Price: 92588.75, Size: -0.013531, PnL: -31.48
# 2025-04-23: Pending order cleared
# 2025-04-23: Order Failed: Status=Canceled, Size=-0.013531, Price=94449.83
# 2025-04-23: Pending order cleared due to failure
# Sizer: Position size: 0.013295, cash=273.51, price=92574.00, margin_required=246.16
# 2025-04-23: TAIL → SELL ORDER PLACED: Price=92574.00, TP=91185.39, SL=93036.87
# 2025-04-23: SELL EXECUTED (OPEN SHORT), Price: 92575.00, Size: -0.013295
# 2025-04-23: Pending order cleared
# 2025-04-23: BUY EXECUTED (CLOSE SHORT), Price: 93036.87, Size: 0.013295, PnL: 30.70
# 2025-04-23: Pending order cleared
# 2025-04-23: Order Failed: Status=Canceled, Size=0.013295, Price=91185.39
# 2025-04-23: Pending order cleared due to failure
# Sizer: Position size: 0.012923, cash=267.37, price=93099.98, margin_required=240.63
# 2025-04-23: HEAD → BUY ORDER PLACED: Price=93099.98, TP=94496.48, SL=92634.48
# 2025-04-23: BUY EXECUTED (OPEN LONG), Price: 93020.00, Size: 0.012923
# 2025-04-23: Pending order cleared
# 2025-04-23: SELL EXECUTED (CLOSE LONG), Price: 92634.48, Size: -0.012923, PnL: -24.91
# 2025-04-23: Pending order cleared
# 2025-04-23: Order Failed: Status=Canceled, Size=-0.012923, Price=94496.48
# 2025-04-23: Pending order cleared due to failure
# Sizer: Position size: 0.012752, cash=262.39, price=92592.72, margin_required=236.15
# 2025-04-23: TAIL → SELL ORDER PLACED: Price=92592.72, TP=91203.83, SL=93055.68
# 2025-04-23: SELL EXECUTED (OPEN SHORT), Price: 92849.97, Size: -0.012752
# 2025-04-23: Pending order cleared
# 2025-04-23: BUY EXECUTED (CLOSE SHORT), Price: 93055.68, Size: 0.012752, PnL: 13.12
# 2025-04-23: Pending order cleared
# 2025-04-23: Order Failed: Status=Canceled, Size=0.012752, Price=91203.83
# 2025-04-23: Pending order cleared due to failure
# Sizer: Position size: 0.012556, cash=259.76, price=93095.93, margin_required=233.79
# 2025-04-23: TAIL → SELL ORDER PLACED: Price=93095.93, TP=91699.49, SL=93561.41
# 2025-04-23: SELL EXECUTED (OPEN SHORT), Price: 93095.93, Size: -0.012556
# 2025-04-23: Pending order cleared
# 2025-04-24: BUY EXECUTED (CLOSE SHORT), Price: 91699.49, Size: 0.012556, PnL: -87.67
# 2025-04-24: Pending order cleared
# 2025-04-24: Order Failed: Status=Canceled, Size=0.012556, Price=93561.41
# 2025-04-24: Pending order cleared due to failure
# Sizer: Position size: 0.013593, cash=277.30, price=91799.00, margin_required=249.57
# 2025-04-24: HEAD → BUY ORDER PLACED: Price=91799.00, TP=93175.98, SL=91340.01
# 2025-04-24: BUY EXECUTED (OPEN LONG), Price: 91799.00, Size: 0.013593
# 2025-04-24: Pending order cleared
# 2025-04-24: SELL EXECUTED (CLOSE LONG), Price: 91340.00, Size: -0.013593, PnL: -31.20
# 2025-04-24: Pending order cleared
# 2025-04-24: Order Failed: Status=Canceled, Size=-0.013593, Price=93175.98
# 2025-04-24: Pending order cleared due to failure
# Sizer: Position size: 0.013355, cash=271.06, price=91333.00, margin_required=243.95
# 2025-04-24: HEAD → BUY ORDER PLACED: Price=91333.00, TP=92702.99, SL=90876.34
# 2025-04-24: BUY EXECUTED (OPEN LONG), Price: 91333.00, Size: 0.013355
# 2025-04-24: Pending order cleared
# 2025-04-24: SELL EXECUTED (CLOSE LONG), Price: 92702.99, Size: -0.013355, PnL: 91.48
# 2025-04-24: Pending order cleared
# 2025-04-24: Order Failed: Status=Canceled, Size=-0.013355, Price=90876.34
# 2025-04-24: Pending order cleared due to failure
# Sizer: Position size: 0.014018, cash=289.35, price=92888.00, margin_required=260.42
# 2025-04-24: TAIL → SELL ORDER PLACED: Price=92888.00, TP=91494.68, SL=93352.44
# 2025-04-24: SELL EXECUTED (OPEN SHORT), Price: 92850.01, Size: -0.014018
# 2025-04-24: Pending order cleared
# 2025-04-24: BUY EXECUTED (CLOSE SHORT), Price: 91494.68, Size: 0.014018, PnL: -94.99
# 2025-04-24: Pending order cleared
# 2025-04-24: Order Failed: Status=Canceled, Size=0.014018, Price=93352.44
# 2025-04-24: Pending order cleared due to failure
# Sizer: Position size: 0.015047, cash=308.35, price=92217.37, margin_required=277.52
# 2025-04-24: HEAD → BUY ORDER PLACED: Price=92217.37, TP=93600.63, SL=91756.28
# 2025-04-24: BUY EXECUTED (OPEN LONG), Price: 92350.00, Size: 0.015047
# 2025-04-24: Pending order cleared
# 2025-04-24: SELL EXECUTED (CLOSE LONG), Price: 93600.63, Size: -0.015047, PnL: 94.09
# 2025-04-24: Pending order cleared
# 2025-04-24: Order Failed: Status=Canceled, Size=-0.015047, Price=91756.28
# 2025-04-24: Pending order cleared due to failure
# Sizer: Position size: 0.015742, cash=327.17, price=93525.00, margin_required=294.45
# 2025-04-24: TAIL → SELL ORDER PLACED: Price=93525.00, TP=92122.12, SL=93992.62
# 2025-04-24: SELL EXECUTED (OPEN SHORT), Price: 93525.00, Size: -0.015742
# 2025-04-24: Pending order cleared

# %%
# Print results
print(f"Final Portfolio Value: {cerebro.broker.getvalue():.2f}")
print(f"Sharpe Ratio: {strat.analyzers.sharpe.get_analysis()}")
print(f"SQN: {strat.analyzers.sqn.get_analysis()}")
print(f"Drawdown: {strat.analyzers.drawdown.get_analysis()}")
print("Trade Analyzer:")
for key, value in strat.analyzers.trades.get_analysis().items():
    print(f"  {key}: {value}")
print(f"Heads: {strat.heads}, Tails: {strat.tails}")

# Print PnL for each trade
print("\nTrade PnL Summary:")
if strat.trade_pnls:
    for i, pnl in enumerate(strat.trade_pnls, 1):
        print(f"Trade {i}: PnL = {pnl:.2f}")
    print(f"Total PnL: {sum(strat.trade_pnls):.2f}")
    print(f"Average PnL: {sum(strat.trade_pnls) / len(strat.trade_pnls):.2f}")
else:
    print("No trades executed.")
# Out:
# Final Portfolio Value: 330.71
# Sharpe Ratio: OrderedDict({'sharperatio': None})
# SQN: AutoOrderedDict({'sqn': -1.6394603659091427, 'trades': 285})
# Drawdown: AutoOrderedDict({'len': 37325, 'drawdown': 78.42374560442528, 'moneydown': 1202.0533434975541, 'max': AutoOrderedDict({'len': 37325, 'drawdown': 85.7907821639898, 'moneydown': 1314.972853524037})})
# Trade Analyzer:
#   total: AutoOrderedDict({'total': 286, 'open': 1, 'closed': 285})
#   streak: AutoOrderedDict({'won': AutoOrderedDict({'current': 3, 'longest': 6}), 'lost': AutoOrderedDict({'current': 0, 'longest': 18})})
#   pnl: AutoOrderedDict({'gross': AutoOrderedDict({'total': -672.8107147887201, 'average': -2.36073935013586}), 'net': AutoOrderedDict({'total': -672.8282190240666, 'average': -2.360800768505497})})
#   won: AutoOrderedDict({'total': 67, 'pnl': AutoOrderedDict({'total': 2237.3554869497016, 'average': 33.39336547686122, 'max': 97.90145634654597})})
#   lost: AutoOrderedDict({'total': 218, 'pnl': AutoOrderedDict({'total': -2910.1837059737686, 'average': -13.349466541164077, 'max': -92.34742408252065})})
#   long: AutoOrderedDict({'total': 144, 'pnl': AutoOrderedDict({'total': -365.79296326611137, 'average': -2.540228911570218, 'won': AutoOrderedDict({'total': 1148.3910608560489, 'average': 32.81117316731568, 'max': 97.90145634654597}), 'lost': AutoOrderedDict({'total': -1514.184024122161, 'average': -13.891596551579457, 'max': -45.939830143273625})}), 'won': 35, 'lost': 109})
#   short: AutoOrderedDict({'total': 141, 'pnl': AutoOrderedDict({'total': -307.0352557579549, 'average': -2.177555005375567, 'won': AutoOrderedDict({'total': 1088.9644260936543, 'average': 34.0301383154267, 'max': 92.09713043391399}), 'lost': AutoOrderedDict({'total': -1395.9996818516101, 'average': -12.807336530748717, 'max': -92.34742408252065})}), 'won': 32, 'lost': 109})
#   len: AutoOrderedDict({'total': 39651, 'average': 139.1263157894737, 'max': 2262, 'min': 1, 'won': AutoOrderedDict({'total': 14944, 'average': 223.044776119403, 'max': 1963, 'min': 1}), 'lost': AutoOrderedDict({'total': 24707, 'average': 113.3348623853211, 'max': 2262, 'min': 1}), 'long': AutoOrderedDict({'total': 16941, 'average': 117.64583333333333, 'max': 917, 'min': 1, 'won': AutoOrderedDict({'total': 6400, 'average': 182.85714285714286, 'max': 851, 'min': 1}), 'lost': AutoOrderedDict({'total': 10541, 'average': 96.70642201834862, 'max': 917, 'min': 1})}), 'short': AutoOrderedDict({'total': 22710, 'average': 161.06382978723406, 'max': 2262, 'min': 1, 'won': AutoOrderedDict({'total': 8544, 'average': 267.0, 'max': 1963, 'min': 1}), 'lost': AutoOrderedDict({'total': 14166, 'average': 129.96330275229357, 'max': 2262, 'min': 1})})})
# Heads: 144, Tails: 142
#
# Trade PnL Summary:
# Trade 1: PnL = -337.47
# Trade 2: PnL = -360.28
# Trade 3: PnL = -393.81
# Trade 4: PnL = 431.19
# Trade 5: PnL = 441.06
# Trade 6: PnL = 259.12
# Trade 7: PnL = 461.74
# Trade 8: PnL = -60.82
# Trade 9: PnL = -460.49
# Trade 10: PnL = -163.86
# Trade 11: PnL = 489.51
# Trade 12: PnL = 171.18
# Trade 13: PnL = -167.33
# Trade 14: PnL = -163.57
# Trade 15: PnL = 159.81
# Trade 16: PnL = -229.70
# Trade 17: PnL = 150.59
# Trade 18: PnL = -144.80
# Trade 19: PnL = -158.40
# Trade 20: PnL = -140.91
# Trade 21: PnL = 137.40
# Trade 22: PnL = -134.53
# Trade 23: PnL = 136.54
# Trade 24: PnL = 176.34
# Trade 25: PnL = -124.58
# Trade 26: PnL = 124.75
# Trade 27: PnL = 99.51
# Trade 28: PnL = -144.93
# Trade 29: PnL = 118.43
# Trade 30: PnL = 332.43
# Trade 31: PnL = -118.29
# Trade 32: PnL = -332.71
# Trade 33: PnL = 369.34
# Trade 34: PnL = -132.05
# Trade 35: PnL = 128.45
# Trade 36: PnL = -128.75
# Trade 37: PnL = 122.66
# Trade 38: PnL = 119.90
# Trade 39: PnL = 104.27
# Trade 40: PnL = 114.86
# Trade 41: PnL = -112.28
# Trade 42: PnL = 89.21
# Trade 43: PnL = -128.76
# Trade 44: PnL = 233.48
# Trade 45: PnL = -110.10
# Trade 46: PnL = -179.63
# Trade 47: PnL = -88.50
# Trade 48: PnL = -303.80
# Trade 49: PnL = -108.42
# Trade 50: PnL = -105.98
# Trade 51: PnL = 315.35
# Trade 52: PnL = -345.31
# Trade 53: PnL = 103.93
# Trade 54: PnL = 116.13
# Trade 55: PnL = -113.51
# Trade 56: PnL = -110.96
# Trade 57: PnL = 122.91
# Trade 58: PnL = -107.48
# Trade 59: PnL = -52.30
# Trade 60: PnL = -76.58
# Trade 61: PnL = 100.38
# Trade 62: PnL = 98.11
# Trade 63: PnL = 95.91
# Trade 64: PnL = 126.19
# Trade 65: PnL = -94.39
# Trade 66: PnL = 88.79
# Trade 67: PnL = -86.79
# Trade 68: PnL = -87.56
# Trade 69: PnL = 82.87
# Trade 70: PnL = -243.02
# Trade 71: PnL = -259.42
# Trade 72: PnL = -81.60
# Trade 73: PnL = -94.98
# Trade 74: PnL = -88.34
# Trade 75: PnL = -86.13
# Trade 76: PnL = -99.78
# Trade 77: PnL = 82.17
# Trade 78: PnL = -111.81
# Trade 79: PnL = -79.93
# Trade 80: PnL = -99.91
# Trade 81: PnL = 84.53
# Trade 82: PnL = -71.85
# Trade 83: PnL = 71.95
# Trade 84: PnL = -51.40
# Trade 85: PnL = 65.62
# Trade 86: PnL = -81.88
# Trade 87: PnL = 192.43
# Trade 88: PnL = 86.59
# Trade 89: PnL = -83.12
# Trade 90: PnL = 81.00
# Trade 91: PnL = -47.47
# Trade 92: PnL = -63.18
# Trade 93: PnL = -46.53
# Trade 94: PnL = 59.30
# Trade 95: PnL = -57.96
# Trade 96: PnL = -56.66
# Trade 97: PnL = -70.03
# Trade 98: PnL = -53.81
# Trade 99: PnL = -157.79
# Trade 100: PnL = -57.49
# Trade 101: PnL = 54.85
# Trade 102: PnL = 160.86
# Trade 103: PnL = 57.24
# Trade 104: PnL = -55.95
# Trade 105: PnL = -54.69
# Trade 106: PnL = 42.08
# Trade 107: PnL = 52.51
# Trade 108: PnL = -51.33
# Trade 109: PnL = 50.18
# Trade 110: PnL = 22.24
# Trade 111: PnL = 48.55
# Trade 112: PnL = -149.10
# Trade 113: PnL = 44.21
# Trade 114: PnL = -42.65
# Trade 115: PnL = 44.47
# Trade 116: PnL = 81.65
# Trade 117: PnL = 142.51
# Trade 118: PnL = 147.67
# Trade 119: PnL = -53.98
# Trade 120: PnL = -51.33
# Trade 121: PnL = -50.18
# Trade 122: PnL = -71.55
# Trade 123: PnL = -47.44
# Trade 124: PnL = 46.27
# Trade 125: PnL = 59.44
# Trade 126: PnL = -87.75
# Trade 127: PnL = 108.08
# Trade 128: PnL = -141.38
# Trade 129: PnL = 49.30
# Trade 130: PnL = 85.11
# Trade 131: PnL = -47.28
# Trade 132: PnL = -138.66
# Trade 133: PnL = 20.38
# Trade 134: PnL = -52.04
# Trade 135: PnL = 143.13
# Trade 136: PnL = -50.93
# Trade 137: PnL = -50.72
# Trade 138: PnL = 155.78
# Trade 139: PnL = 57.39
# Trade 140: PnL = 45.60
# Trade 141: PnL = -149.49
# Trade 142: PnL = -83.22
# Trade 143: PnL = -56.53
# Trade 144: PnL = -152.69
# Trade 145: PnL = 11.94
# Trade 146: PnL = -109.35
# Trade 147: PnL = 156.57
# Trade 148: PnL = -80.21
# Trade 149: PnL = -57.93
# Trade 150: PnL = 56.63
# Trade 151: PnL = -116.29
# Trade 152: PnL = -62.55
# Trade 153: PnL = -56.56
# Trade 154: PnL = 55.29
# Trade 155: PnL = 54.05
# Trade 156: PnL = 104.92
# Trade 157: PnL = -45.24
# Trade 158: PnL = -71.04
# Trade 159: PnL = -47.84
# Trade 160: PnL = 81.42
# Trade 161: PnL = 65.99
# Trade 162: PnL = 46.39
# Trade 163: PnL = 40.10
# Trade 164: PnL = 41.51
# Trade 165: PnL = -54.23
# Trade 166: PnL = -41.02
# Trade 167: PnL = -33.41
# Trade 168: PnL = 92.51
# Trade 169: PnL = 54.97
# Trade 170: PnL = -29.57
# Trade 171: PnL = 18.18
# Trade 172: PnL = 38.58
# Trade 173: PnL = -109.76
# Trade 174: PnL = 47.33
# Trade 175: PnL = 59.08
# Trade 176: PnL = -36.66
# Trade 177: PnL = 35.84
# Trade 178: PnL = 35.03
# Trade 179: PnL = 33.69
# Trade 180: PnL = 33.48
# Trade 181: PnL = -32.73
# Trade 182: PnL = 24.04
# Trade 183: PnL = 94.36
# Trade 184: PnL = 54.34
# Trade 185: PnL = 40.32
# Trade 186: PnL = -31.45
# Trade 187: PnL = 66.11
# Trade 188: PnL = -31.85
# Trade 189: PnL = 32.63
# Trade 190: PnL = -82.57
# Trade 191: PnL = -34.13
# Trade 192: PnL = -101.96
# Trade 193: PnL = 102.73
# Trade 194: PnL = -34.86
# Trade 195: PnL = 1.95
# Trade 196: PnL = 106.93
# Trade 197: PnL = 38.05
# Trade 198: PnL = -40.63
# Trade 199: PnL = -9.59
# Trade 200: PnL = 22.30
# Trade 201: PnL = -27.01
# Trade 202: PnL = -34.95
# Trade 203: PnL = 112.23
# Trade 204: PnL = -96.78
# Trade 205: PnL = 38.87
# Trade 206: PnL = 38.00
# Trade 207: PnL = 111.42
# Trade 208: PnL = 39.65
# Trade 209: PnL = -38.76
# Trade 210: PnL = 55.73
# Trade 211: PnL = 31.17
# Trade 212: PnL = 35.93
# Trade 213: PnL = -35.12
# Trade 214: PnL = -34.33
# Trade 215: PnL = 20.37
# Trade 216: PnL = -37.94
# Trade 217: PnL = -96.69
# Trade 218: PnL = 103.26
# Trade 219: PnL = -110.23
# Trade 220: PnL = 115.06
# Trade 221: PnL = 37.86
# Trade 222: PnL = -40.96
# Trade 223: PnL = 57.39
# Trade 224: PnL = 47.23
# Trade 225: PnL = -38.57
# Trade 226: PnL = -89.73
# Trade 227: PnL = 39.21
# Trade 228: PnL = 66.91
# Trade 229: PnL = -36.45
# Trade 230: PnL = 21.95
# Trade 231: PnL = 39.17
# Trade 232: PnL = -121.64
# Trade 233: PnL = -39.01
# Trade 234: PnL = 30.94
# Trade 235: PnL = 27.18
# Trade 236: PnL = -34.81
# Trade 237: PnL = -30.05
# Trade 238: PnL = 29.36
# Trade 239: PnL = 42.26
# Trade 240: PnL = -26.48
# Trade 241: PnL = 35.42
# Trade 242: PnL = -30.34
# Trade 243: PnL = 29.65
# Trade 244: PnL = -28.99
# Trade 245: PnL = -32.36
# Trade 246: PnL = 82.84
# Trade 247: PnL = 29.48
# Trade 248: PnL = 20.44
# Trade 249: PnL = 28.35
# Trade 250: PnL = -27.71
# Trade 251: PnL = 34.93
# Trade 252: PnL = 5.04
# Trade 253: PnL = 26.19
# Trade 254: PnL = 25.60
# Trade 255: PnL = -23.26
# Trade 256: PnL = -73.51
# Trade 257: PnL = 78.47
# Trade 258: PnL = 27.92
# Trade 259: PnL = 81.82
# Trade 260: PnL = 28.42
# Trade 261: PnL = -28.50
# Trade 262: PnL = 27.85
# Trade 263: PnL = -27.23
# Trade 264: PnL = 26.67
# Trade 265: PnL = -78.05
# Trade 266: PnL = -2.81
# Trade 267: PnL = 83.12
# Trade 268: PnL = 29.70
# Trade 269: PnL = -29.04
# Trade 270: PnL = 85.15
# Trade 271: PnL = 32.89
# Trade 272: PnL = -31.32
# Trade 273: PnL = -86.56
# Trade 274: PnL = 28.23
# Trade 275: PnL = 90.50
# Trade 276: PnL = -32.20
# Trade 277: PnL = -31.48
# Trade 278: PnL = 30.70
# Trade 279: PnL = -24.91
# Trade 280: PnL = 13.12
# Trade 281: PnL = -87.67
# Trade 282: PnL = -31.20
# Trade 283: PnL = 91.48
# Trade 284: PnL = -94.99
# Trade 285: PnL = 94.09
# Total PnL: -293.78
# Average PnL: -1.03
